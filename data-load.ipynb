# %% [markdown]
# # Introduction
#
# This notedbook loads and processed the source data to make it ready for RAG system. I am experimenting with publicly available
# - [Patient-level Clinical Drug Trial Data](https://www.kaggle.com/datasets/dillonmyrick/bells-palsy-clinical-trial)
# - [COVID-19 Clinical Trials dataset](https://www.kaggle.com/datasets/parulpandey/covid19-clinical-trials-dataset)
#
# datasets from Kaggle. The two datasets are fundamentally different. The former has more int or bool data fields, while the latter is semi-structured that has fields like trial title and outcome measures.

# %%
import pandas as pd

# %% [markdown]
# ## Data Processing
#
# The input data is the [COVID-19 Clinical Trials dataset]('https://www.kaggle.com/datasets/parulpandey/covid19-clinical-trials-dataset') a data set in csv format from Kaggle. Using __pandas__ package, I am loading the data into a data frame and getting some descriptive statistics using the *Describe*.

# %%
## load the clinical trial data from file to dataframe for analysis
df_CT_cancer = pd.read_csv('./data/COVID_clinical_trials.csv')
df_CT_cancer.head()
# Out:
#    Rank   NCT Number                                              Title  \
# 0     1  NCT04785898  Diagnostic Performance of the ID Now™ COVID-19...
# 1     2  NCT04595136  Study to Evaluate the Efficacy of COVID19-0001...
# 2     3  NCT04395482  Lung CT Scan Analysis of SARS-CoV2 Induced Lun...
# 3     4  NCT04416061  The Role of a Private Hospital in Hong Kong Am...
# 4     5  NCT04395924         Maternal-foetal Transmission of SARS-Cov-2
#
#         Acronym                  Status         Study Results  \
# 0   COVID-IDNow  Active, not recruiting  No Results Available
# 1      COVID-19      Not yet recruiting  No Results Available
# 2   TAC-COVID19              Recruiting  No Results Available
# 3      COVID-19  Active, not recruiting  No Results Available
# 4  TMF-COVID-19              Recruiting  No Results Available
#
#                                           Conditions  \
# 0                                            Covid19
# 1                               SARS-CoV-2 Infection
# 2                                            covid19
# 3                                              COVID
# 4  Maternal Fetal Infection Transmission|COVID-19...
#
#                                        Interventions  \
# 0   Diagnostic Test: ID Now™ COVID-19 Screening Test
# 1    Drug: Drug COVID19-0001-USR|Drug: normal saline
# 2  Other: Lung CT scan analysis in COVID-19 patients
# 3          Diagnostic Test: COVID 19 Diagnostic Test
# 4  Diagnostic Test: Diagnosis of SARS-Cov2 by RT-...
#
#                                     Outcome Measures  \
# 0  Evaluate the diagnostic performance of the ID ...
# 1  Change on viral load results from baseline aft...
# 2  A qualitative analysis of parenchymal lung dam...
# 3  Proportion of asymptomatic subjects|Proportion...
# 4  COVID-19 by positive PCR in cord blood and / o...
#
#                                Sponsor/Collaborators  ...         Other IDs  \
# 0              Groupe Hospitalier Paris Saint Joseph  ...       COVID-IDNow
# 1                         United Medical Specialties  ...  COVID19-0001-USR
# 2                       University of Milano Bicocca  ...       TAC-COVID19
# 3                    Hong Kong Sanatorium & Hospital  ...        RC-2020-08
# 4  Centre Hospitalier Régional d'Orléans|Centre d...  ...      CHRO-2020-10
#
#          Start Date Primary Completion Date   Completion Date  \
# 0  November 9, 2020       December 22, 2020    April 30, 2021
# 1  November 2, 2020       December 15, 2020  January 29, 2021
# 2       May 7, 2020           June 15, 2021     June 15, 2021
# 3      May 25, 2020           July 31, 2020   August 31, 2020
# 4       May 5, 2020                May 2021          May 2021
#
#        First Posted Results First Posted Last Update Posted  \
# 0     March 8, 2021                  NaN      March 8, 2021
# 1  October 20, 2020                  NaN   October 20, 2020
# 2      May 20, 2020                  NaN   November 9, 2020
# 3      June 4, 2020                  NaN       June 4, 2020
# 4      May 20, 2020                  NaN       June 4, 2020
#
#                                            Locations Study Documents  \
# 0  Groupe Hospitalier Paris Saint-Joseph, Paris, ...             NaN
# 1       Cimedical, Barranquilla, Atlantico, Colombia             NaN
# 2  Ospedale Papa Giovanni XXIII, Bergamo, Italy|P...             NaN
# 3  Hong Kong Sanatorium & Hospital, Hong Kong, Ho...             NaN
# 4                       CHR Orléans, Orléans, France             NaN
#
#                                            URL
# 0  https://ClinicalTrials.gov/show/NCT04785898
# 1  https://ClinicalTrials.gov/show/NCT04595136
# 2  https://ClinicalTrials.gov/show/NCT04395482
# 3  https://ClinicalTrials.gov/show/NCT04416061
# 4  https://ClinicalTrials.gov/show/NCT04395924
#
# [5 rows x 27 columns]

# %%
## Dataset statistics like total acount & data distribution values (mean / std )
df_CT_cancer.describe()
# Out:
#               Rank    Enrollment
# count  5783.000000  5.749000e+03
# mean   2892.000000  1.831949e+04
# std    1669.552635  4.045437e+05
# min       1.000000  0.000000e+00
# 25%    1446.500000  6.000000e+01
# 50%    2892.000000  1.700000e+02
# 75%    4337.500000  5.600000e+02
# max    5783.000000  2.000000e+07

# %%
# remove empty values 
df_CT_cancer = df_CT_cancer[df_CT_cancer['Title'].notna()]
df_CT_cancer = df_CT_cancer[df_CT_cancer['Study Documents'].notna()]

df_CT_cancer.describe()
# Out:
#               Rank     Enrollment
# count   182.000000      179.00000
# mean   3158.406593    10216.96648
# std    1821.715884    82183.01819
# min      20.000000        1.00000
# 25%    1579.250000       50.00000
# 50%    3057.500000      200.00000
# 75%    5017.000000      880.00000
# max    5771.000000  1000000.00000

# %%
## Convert dataframe to dictionary as a preparation to create the embedding (vectorised data). 
## The data is stored in key-value format
df_CT_cancer.to_dict('records')
# Out:
# [{'Rank': 20,
#   'NCT Number': 'NCT04407585',
#   'Title': 'Testing the Accuracy of a Digital Test to Diagnose Covid-19',
#   'Acronym': nan,
#   'Status': 'Recruiting',
#   'Study Results': 'No Results Available',
#   'Conditions': 'Covid-19',
#   'Interventions': 'Diagnostic Test: Covid-19 swab PCR test',
#   'Outcome Measures': 'SARS-CoV-2 infection',
#   'Sponsor/Collaborators': "King's College London|Zoe Global Limited|Department of Health, United Kingdom",
#   'Gender': 'All',
#   'Age': '18 Years and older \xa0 (Adult, Older Adult)',
#   'Phases': nan,
#   'Enrollment': 1000000.0,
#   'Funded Bys': 'Other',
#   'Study Type': 'Observational',
#   'Study Designs': 'Observational Model: Cohort|Time Perspective: Prospective',
#   'Other IDs': 'Covid-19 Validation Study',
#   'Start Date': 'June 1, 2020',
#   'Primary Completion Date': 'May 10, 2021',
#   'Completion Date': 'May 10, 2021',
#   'First Posted': 'May 29, 2020',
#   'Results First Posted': nan,
#   'Last Update Posted': 'June 24, 2020',
#   'Locations': "King's College London, London, United Kingdom",
#   'Study Documents': '"Statistical Analysis Plan", https://ClinicalTrials.gov/ProvidedDocs/85/NCT04407585/SAP_000.pdf',
#   'URL': 'https://ClinicalTrials.gov/show/NCT04407585'},
#  {'Rank': 71,
#   'NCT Number': 'NCT04674644',
#   'Title': 'Analysing the Psychosocial Effects of COVID-19 Pandemic on Dental Professionals Using the Turkish Version of the Fear of COVID-19 and Coronavirus Anxiety Scales',
#   'Acronym': nan,
#   'Status': 'Completed',
#   'Study Results': 'Has Results',
#   'Conditions': 'COVID-19 Pandemic',
#   'Interventions': 'Behavioral: The psychosocial effects of COVID-19 pandemic on dental professionals',
#   'Outcome Measures': 'The Psychosocial Effects of COVID-19 Pandemic on Dental Professionals Using the Turkish Version of the Fear of COVID-19 Scale|The Psychosocial Effects of COVID-19 Pandemic Using the Turkish Version of the Coronavirus Anxiety Scale',
#   'Sponsor/Collaborators': 'Suleyman Demirel University',
#   'Gender': 'All',
#   'Age': '23 Years and older \xa0 (Adult, Older Adult)',
#   'Phases': 'Not Applicable',
#   'Enrollment': 850.0,
#   'Funded Bys': 'Other',
#   'Study Type': 'Interventional',
#   'Study Designs': 'Allocation: N/A|Intervention Model: Single Group Assignment|Masking: None (Open Label)|Primary Purpose: Other',
#   'Other IDs': '355',
#   'Start Date': 'October 16, 2020',
#   'Primary Completion Date': 'October 23, 2020',
#   'Completion Date': 'October 23, 2020',
#   'First Posted': 'December 19, 2020',
#   'Results First Posted': 'January 29, 2021',
#   'Last Update Posted': 'February 2, 2021',
#   'Locations': 'Suleyman Demirel University Faculty of Dentistry Pediatric Dentistry Department, Isparta, Turkey',
#   'Study Documents': '"Study Protocol and Statistical Analysis Plan", https://ClinicalTrials.gov/ProvidedDocs/44/NCT04674644/Prot_SAP_000.pdf',
#   'URL': 'https://ClinicalTrials.gov/show/NCT04674644'},
#  {'Rank': 84,
#   'NCT Number': 'NCT04816318',
#   'Title': 'Policy Responses Against the COVID-19 Pandemic in Latin America',
#   'Acronym': nan,
#   'Status': 'Not yet recruiting',
#   'Study Results': 'No Results Available',
#   'Conditions': 'Covid19|Infectious Disease|Death|SARS-CoV Infection',
#   'Interventions': 'Other: Social and public health measures against COVID-19|Other: Control',
#   'Outcome Measures': '7-day moving average of daily confirmed cases of COVID-19/SARS-CoV-2|Time-varying reproductive number of confirmed cases of COVID-19/SARS-CoV-2|7-day moving average of daily confirmed deaths of COVID-19/SARS-CoV-2',
#   'Sponsor/Collaborators': 'University of Chile',
#   'Gender': 'All',
#   'Age': 'Child, Adult, Older Adult',
#   'Phases': nan,
#   'Enrollment': 10000.0,
#   'Funded Bys': 'Other',
#   'Study Type': 'Observational',
#   'Study Designs': 'Observational Model: Ecologic or Community|Time Perspective: Prospective',
#   'Other IDs': 'ANID-COVID 0960',
#   'Start Date': 'March 22, 2021',
#   'Primary Completion Date': 'May 31, 2021',
#   'Completion Date': 'May 31, 2021',
#   'First Posted': 'March 25, 2021',
#   'Results First Posted': nan,
#   'Last Update Posted': 'March 29, 2021',
#   'Locations': 'Escuela de Salud Pública, Santiago, Región Metropolitana, Chile',
#   'Study Documents': '"Statistical Analysis Plan", https://ClinicalTrials.gov/ProvidedDocs/18/NCT04816318/SAP_000.pdf|"Study Protocol", https://ClinicalTrials.gov/ProvidedDocs/18/NCT04816318/Prot_001.pdf',
#   'URL': 'https://ClinicalTrials.gov/show/NCT04816318'},
#  {'Rank': 87,
#   'NCT Number': 'NCT04474496',
#   'Title': 'Impact of COVID-19 on Marshallese Communities in the U.S.',
#   'Acronym': nan,
#   'Status': 'Completed',
#   'Study Results': 'Has Results',
#   'Conditions': 'COVID-19',
#   'Interventions': 'Other: Assessing the impact of COVID-19',
#   'Outcome Measures': 'Personal Preventative Behaviors to Decrease Risk of COVID-19 Exposure|Workplace Preventative Actions to Decrease Risk of COVID-19 Exposure|Effects of COVID-19 on General Health Status|Effects of COVID-19 on Access to Healthcare Services|Effects of COVID-19 on Dietary Habits|Effects of COVID-19 on Physical Activity Behaviors (Not Specifically for Exercise)|Effects of COVID-19 on Physical Activity Behaviors (Specifically for Exercise)|Effects of COVID-19 on Weight|Effects of COVID-19 on HbA1c (Glycated Hemoglobin)|Barriers to Type 2 Diabetes Management Due to COVID-19|COVID-19 Screening|COVID-19 Testing|COVID-19 Vaccine Willingness/Hesitancy|Trusted Sources of COVID-19 Information|Effects of COVID-19 on Housing|Effects of COVID-19 on Employment|Effects of COVID-19 on Income|Sources of Stress During COVID-19',
#   'Sponsor/Collaborators': 'University of Arkansas|Patient-Centered Outcomes Research Institute',
#   'Gender': 'All',
#   'Age': '18 Years and older \xa0 (Adult, Older Adult)',
#   'Phases': nan,
#   'Enrollment': 120.0,
#   'Funded Bys': 'Other',
#   'Study Type': 'Observational',
#   'Study Designs': 'Observational Model: Other|Time Perspective: Cross-Sectional',
#   'Other IDs': '261131',
#   'Start Date': 'July 27, 2020',
#   'Primary Completion Date': 'November 30, 2020',
#   'Completion Date': 'November 30, 2020',
#   'First Posted': 'July 16, 2020',
#   'Results First Posted': 'April 5, 2021',
#   'Last Update Posted': 'April 5, 2021',
#   'Locations': 'University of Arkansas for Medical Sciences Northwest, Fayetteville, Arkansas, United States',
#   'Study Documents': '"Study Protocol and Statistical Analysis Plan", https://ClinicalTrials.gov/ProvidedDocs/96/NCT04474496/Prot_SAP_000.pdf',
#   'URL': 'https://ClinicalTrials.gov/show/NCT04474496'},
#  {'Rank': 112,
#   'NCT Number': 'NCT04713163',
#   'Title': 'COVID-19 Vaccine Induced Immunity',
#   'Acronym': nan,
#   'Status': 'Not yet recruiting',
#   'Study Results': 'No Results Available',
#   'Conditions': 'Covid19',
#   'Interventions': 'Drug: covid19 vaccine',
#   'Outcome Measures': 'Nasal T cell responses|Systemic T cell responses|Systemic and nasal antibody responses',
#   'Sponsor/Collaborators': 'University of Manitoba|Public Health Agency of Canada (PHAC)|Cadham Provincial Lab',
#   'Gender': 'All',
#   'Age': '18 Years and older \xa0 (Adult, Older Adult)',
#   'Phases': nan,
#   'Enrollment': 200.0,
#   'Funded Bys': 'Other',
#   'Study Type': 'Observational',
#   'Study Designs': 'Observational Model: Cohort|Time Perspective: Prospective',
#   'Other IDs': 'B2021:008',
#   'Start Date': 'January 2021',
#   'Primary Completion Date': 'April 2021',
#   'Completion Date': 'December 2021',
#   'First Posted': 'January 19, 2021',
#   'Results First Posted': nan,
#   'Last Update Posted': 'January 19, 2021',
#   'Locations': nan,
#   'Study Documents': '"Study Protocol and Statistical Analysis Plan", https://ClinicalTrials.gov/ProvidedDocs/63/NCT04713163/Prot_SAP_000.pdf',
#   'URL': 'https://ClinicalTrials.gov/show/NCT04713163'},
#  {'Rank': 114,
#   'NCT Number': 'NCT04780126',
#   'Title': 'Sarco-COVID Study: Measuring the Loss of Skeletal Muscle Mass in the Hospitalized Patient With the Diagnosis of COVID-19',
#   'Acronym': 'SARCO-COVID',
#   'Status': 'Recruiting',
#   'Study Results': 'No Results Available',
#   'Conditions': 'Sarcopenia|Covid19',
#   'Interventions': 'Other: Sarcopenia diagnosis',
#   'Outcome Measures': 'Loss of muscle mass|Prevalence of sarcopenia|Normal values of muscle ultrasound thickness|C reactive protein (CRP) correlated to the presence of sarcopenia|Therapy with corticosteroids impact on muscle thickness|Normal values of medial gastrocnemius pennation angle in all patients|Ferritin correlated to the presence of sarcopenia|Fibrinogen correlated to the presence of sarcopenia',
#   'Sponsor/Collaborators': 'Fundacion para la Investigacion Biomedica del Hospital Universitario la Paz',
#   'Gender': 'All',
#   'Age': '18 Years and older \xa0 (Adult, Older Adult)',
#   'Phases': nan,
#   'Enrollment': 64.0,
#   'Funded Bys': 'Other',
#   'Study Type': 'Observational',
#   'Study Designs': 'Observational Model: Ecologic or Community|Time Perspective: Prospective',
#   'Other IDs': '21/090-E_COVID',
#   'Start Date': 'February 26, 2021',
#   'Primary Completion Date': 'April 30, 2021',
#   'Completion Date': 'May 31, 2021',
#   'First Posted': 'March 3, 2021',
#   'Results First Posted': nan,
#   'Last Update Posted': 'March 3, 2021',
#   'Locations': 'Hospital de Emergencias Isabel Zendal, Madrid, Spain',
#   'Study Documents': '"Study Protocol, Statistical Analysis Plan, and Informed Consent Form", https://ClinicalTrials.gov/ProvidedDocs/26/NCT04780126/Prot_SAP_ICF_000.pdf',
#   'URL': 'https://ClinicalTrials.gov/show/NCT04780126'},
#  {'Rank': 126,
#   'NCT Number': 'NCT04410549',
#   'Title': 'Pulmonary Optical Coherence Tomography in COVID-19 Patients',
#   'Acronym': nan,
#   'Status': 'Recruiting',
#   'Study Results': 'No Results Available',
#   'Conditions': 'Covid19|Pulmonary Embolism',
#   'Interventions': 'Diagnostic Test: Optical Coherence Tomography (OCT)',
#   'Outcome Measures': 'optical coherence tomography pulmonary microthrombosis assessment in COVID-19 pneumonia patients|Pulmonary artery vessel anatomy characterization|Correlation between TTE pulmonary hypertension and right ventricular disfunction|Correlations with standard inflammatory, coagulation and tissue damage',
#   'Sponsor/Collaborators': 'IRCCS San Raffaele',
#   'Gender': 'All',
#   'Age': '18 Years and older \xa0 (Adult, Older Adult)',
#   'Phases': 'Not Applicable',
#   'Enrollment': 10.0,
#   'Funded Bys': 'Other',
#   'Study Type': 'Interventional',
#   'Study Designs': 'Allocation: N/A|Intervention Model: Single Group Assignment|Masking: None (Open Label)|Primary Purpose: Diagnostic',
#   'Other IDs': 'OCT COVID',
#   'Start Date': 'June 1, 2020',
#   'Primary Completion Date': 'December 31, 2021',
#   'Completion Date': 'December 31, 2021',
#   'First Posted': 'June 1, 2020',
#   'Results First Posted': nan,
#   'Last Update Posted': 'February 25, 2021',
#   'Locations': 'Incor - Heart Institute - University of Sao Paulo, São Paulo, Brazil|IRCCS San Raffaele, Milano, Italy',
#   'Study Documents': '"Study Protocol", https://ClinicalTrials.gov/ProvidedDocs/49/NCT04410549/Prot_000.pdf',
#   'URL': 'https://ClinicalTrials.gov/show/NCT04410549'},
#  {'Rank': 251,
#   'NCT Number': 'NCT04341441',
#   'Title': 'Will Hydroxychloroquine Impede or Prevent COVID-19',
#   'Acronym': 'WHIP COVID-19',
#   'Status': 'Terminated',
#   'Study Results': 'No Results Available',
#   'Conditions': 'COVID-19|Coronavirus|Coronavirus Infections|SARS-CoV 2',
#   'Interventions': 'Drug: Hydroxychloroquine - Daily Dosing|Drug: Hydroxychloroquine - Weekly Dosing|Other: Placebo oral tablet|Diagnostic Test: Monitoring Visit - Baseline|Diagnostic Test: Monitoring Visit - Week 4|Diagnostic Test: Monitoring Visit - Week 8|Other: Weekly Assessment',
#   'Outcome Measures': 'To determine if the use of hydroxychloroquine as preventive therapy decreases the rate of acquisition of SARS-CoV 2 infections and clinical COVID-19 disease in Study Participants for each randomized treatment arm as compared to placebo.|Determine the effect of hydroxychloroquine dose in the prevention of COVID-19 viremia and disease.|Assess the impact of chronic weight-based dosing of HCQ for COVID-19 prevention.|Comparison of the rate of SARS-CoV 2 infections as measured by IgM/IgG seroconversion in study participants receiving randomized HCQ versus placebo.|Compare the seroprevalence of SARS-CoV 2 IgM/IgG positive samples at study entry and study conclusion in all participants receiving HCQ compared to those receiving placebo.|Comparison of the emergence of clinical symptoms or COVID-19 diagnosis in participants presenting asymptomatically at study entry but identified as seropositive by serology at entry between the randomized treatment arms and comparator arm.|To examine the level of care needed by participants in each arm developing COVID19 as measured as requiring emergency room visit, hospitalization or able to stay home without hospital care.|Determine the safety and tolerability of HCQ dosing for preventive strategy against COVID-19 as measured by adverse events and serious adverse events.|To examine other clinical determinants contributing to the risk of SARS-CoV 2 infection in healthcare workers and first responders.|Examine the association between HCQ drug levels and development of COVID-19 symptoms or positive test results.|identify immunologic, serological and inflammatory markers associated with acquisition and response to COVID-19 in both HCQ and placebo Participants developing laboratory or clinical confirmed disease.',
#   'Sponsor/Collaborators': 'Henry Ford Health System',
#   'Gender': 'All',
#   'Age': '18 Years to 75 Years \xa0 (Adult, Older Adult)',
#   'Phases': 'Phase 3',
#   'Enrollment': 624.0,
#   'Funded Bys': 'Other',
#   'Study Type': 'Interventional',
#   'Study Designs': 'Allocation: Randomized|Intervention Model: Parallel Assignment|Masking: Triple (Participant, Care Provider, Investigator)|Primary Purpose: Prevention',
#   'Other IDs': '1410401',
#   'Start Date': 'April 7, 2020',
#   'Primary Completion Date': 'December 15, 2020',
#   'Completion Date': 'December 15, 2020',
#   'First Posted': 'April 10, 2020',
#   'Results First Posted': nan,
#   'Last Update Posted': 'December 21, 2020',
#   'Locations': 'Henry Ford Hospital, Detroit, Michigan, United States|Detroit Department of Transportation (DDOT), Detroit, Michigan, United States|Detroit Fire Department & Detroit EMS, Detroit, Michigan, United States|Detroit Police Department, Detroit, Michigan, United States',
#   'Study Documents': '"Study Protocol", https://ClinicalTrials.gov/ProvidedDocs/41/NCT04341441/Prot_001.pdf',
#   'URL': 'https://ClinicalTrials.gov/show/NCT04341441'},
#  {'Rank': 281,
#   'NCT Number': 'NCT04468256',
#   'Title': 'The Heart Hive COVID-19 Study',
#   'Acronym': nan,
#   'Status': 'Recruiting',
#   'Study Results': 'No Results Available',
#   'Conditions': 'COVID-19|Cardiomyopathies',
#   'Interventions': 'Other: COVID-19 experience surveys',
#   'Outcome Measures': 'Qualitative measures of exposure, perception of risk, behaviour, and experience during the COVID-19 pandemic.|Health Outcomes',
#   'Sponsor/Collaborators': 'Imperial College London',
#   'Gender': 'All',
#   'Age': '18 Years and older \xa0 (Adult, Older Adult)',
#   'Phases': nan,
#   'Enrollment': 1000.0,
#   'Funded Bys': 'Other',
#   'Study Type': 'Observational',
#   'Study Designs': 'Observational Model: Case-Control|Time Perspective: Prospective',
#   'Other IDs': '20IC6036',
#   'Start Date': 'July 26, 2020',
#   'Primary Completion Date': 'July 2022',
#   'Completion Date': 'July 2022',
#   'First Posted': 'July 13, 2020',
#   'Results First Posted': nan,
#   'Last Update Posted': 'September 2, 2020',
#   'Locations': 'Imperial College London, London, United Kingdom',
#   'Study Documents': '"Informed Consent Form", https://ClinicalTrials.gov/ProvidedDocs/56/NCT04468256/ICF_000.pdf',
#   'URL': 'https://ClinicalTrials.gov/show/NCT04468256'},
#  {'Rank': 284,
#   'NCT Number': 'NCT04382781',
#   'Title': 'Immunosupressive Treatment in COVID-19 Patients',
#   'Acronym': 'SAM-COVID',
#   'Status': 'Recruiting',
#   'Study Results': 'No Results Available',
#   'Conditions': 'COVID-19 Infection',
#   'Interventions': 'Drug: NO-Immunosuppressive|Drug: Immunosuppressive|Drug: Immunoglubulins',
#   'Outcome Measures': 'Invasive ventilation or death|Ventilation|Death|Secondary infections|Digestive tract hemorrhage|Change in 7 points scale',
#   'Sponsor/Collaborators': 'Spanish Network for Research in Infectious Diseases|Fundación Pública Andaluza para la gestión de la Investigación en Sevilla',
#   'Gender': 'All',
#   'Age': '18 Years and older \xa0 (Adult, Older Adult)',
#   'Phases': nan,
#   'Enrollment': 500.0,
#   'Funded Bys': 'Other',
#   'Study Type': 'Observational',
#   'Study Designs': 'Observational Model: Cohort|Time Perspective: Retrospective',
#   'Other IDs': 'FIS-INM-2020-03',
#   'Start Date': 'May 2020',
#   'Primary Completion Date': 'May 2020',
#   'Completion Date': 'May 2020',
#   'First Posted': 'May 11, 2020',
#   'Results First Posted': nan,
#   'Last Update Posted': 'May 12, 2020',
#   'Locations': 'Hospital Virgen Macarena, Sevilla, Spain',
#   'Study Documents': '"Study Protocol and Statistical Analysis Plan", https://ClinicalTrials.gov/ProvidedDocs/81/NCT04382781/Prot_SAP_000.pdf',
#   'URL': 'https://ClinicalTrials.gov/show/NCT04382781'},
#  {'Rank': 452,
#   'NCT Number': 'NCT04568356',
#   'Title': 'A Clinical Evaluation of COVID-19 Rapid Point of Care Antigen Tests',
#   'Acronym': nan,
#   'Status': 'Completed',
#   'Study Results': 'No Results Available',
#   'Conditions': 'SARS CoV-2',
#   'Interventions': 'Diagnostic Test: Direct Antigen Tests for COVID-19',
#   'Outcome Measures': 'Percent Positive Agreement and Negative Percent Agreement',
#   'Sponsor/Collaborators': 'E25Bio, Inc.|SCRI Development Innovations, LLC',
#   'Gender': 'All',
#   'Age': '18 Years and older \xa0 (Adult, Older Adult)',
#   'Phases': 'Not Applicable',
#   'Enrollment': 200.0,
#   'Funded Bys': 'Industry|Other',
#   'Study Type': 'Interventional',
#   'Study Designs': 'Allocation: N/A|Intervention Model: Single Group Assignment|Masking: None (Open Label)|Primary Purpose: Diagnostic',
#   'Other IDs': 'E25001_NEU2012',
#   'Start Date': 'April 24, 2020',
#   'Primary Completion Date': 'June 12, 2020',
#   'Completion Date': 'September 24, 2020',
#   'First Posted': 'September 29, 2020',
#   'Results First Posted': nan,
#   'Last Update Posted': 'October 19, 2020',
#   'Locations': 'JFK Medical Center, Miami, Florida, United States|Kendall Regional, Miami, Florida, United States|Aventura Hospital and Medical Center, Miami, Florida, United States',
#   'Study Documents': '"Informed Consent Form", https://ClinicalTrials.gov/ProvidedDocs/56/NCT04568356/ICF_000.pdf|"Study Protocol", https://ClinicalTrials.gov/ProvidedDocs/56/NCT04568356/Prot_001.pdf',
#   'URL': 'https://ClinicalTrials.gov/show/NCT04568356'},
#  {'Rank': 462,
#   'NCT Number': 'NCT04321811',
#   'Title': 'Behavior, Environment And Treatments for Covid-19',
#   'Acronym': 'BEAT19',
#   'Status': 'Active, not recruiting',
#   'Study Results': 'No Results Available',
#   'Conditions': 'Coronavirus',
#   'Interventions': 'Other: Observation of patients with known, suspected, or at risk for COVID-19 infection',
#   'Outcome Measures': 'Define Natural Symptom Course|Time to Hospitalization|Time to Symptomatic Recovery',
#   'Sponsor/Collaborators': 'xCures|Genetic Alliance|LunaDNA|Cancer Commons|REDCap Cloud',
#   'Gender': 'All',
#   'Age': '18 Years and older \xa0 (Adult, Older Adult)',
#   'Phases': nan,
#   'Enrollment': 100000.0,
#   'Funded Bys': 'Industry|Other',
#   'Study Type': 'Observational',
#   'Study Designs': 'Observational Model: Cohort|Time Perspective: Prospective',
#   'Other IDs': 'XC-PCOR-COVID19',
#   'Start Date': 'March 21, 2020',
#   'Primary Completion Date': 'February 9, 2021',
#   'Completion Date': 'March 20, 2022',
#   'First Posted': 'March 25, 2020',
#   'Results First Posted': nan,
#   'Last Update Posted': 'February 10, 2021',
#   'Locations': 'BEAT19.org, San Francisco, California, United States',
#   'Study Documents': '"Study Protocol and Informed Consent Form", https://ClinicalTrials.gov/ProvidedDocs/11/NCT04321811/Prot_ICF_000.pdf',
#   'URL': 'https://ClinicalTrials.gov/show/NCT04321811'},
#  {'Rank': 491,
#   'NCT Number': 'NCT04386239',
#   'Title': 'Study on the Use of Sarilumab in Patients With COVID-19 Infection',
#   'Acronym': nan,
#   'Status': 'Recruiting',
#   'Study Results': 'No Results Available',
#   'Conditions': 'COVID19',
#   'Interventions': 'Drug: Sarilumab Prefilled Syringe',
#   'Outcome Measures': 'Proportion of patients who show an improvement of the respiratory function|Evaluation of the time to resolution of fever|Evaluation of the viral load on blood and sputum for COVID-19|Evaluation of the plasma concentration of GM-CSF|Evaluation of the plasma concentration of Il-6|Evaluation of the plasma concentration of TNF-α|Evaluation of the rate of progression of White Blood Cell (WBC) fraction',
#   'Sponsor/Collaborators': 'ASST Fatebenefratelli Sacco',
#   'Gender': 'All',
#   'Age': '18 Years to 84 Years \xa0 (Adult, Older Adult)',
#   'Phases': 'Early Phase 1',
#   'Enrollment': 40.0,
#   'Funded Bys': 'Other',
#   'Study Type': 'Interventional',
#   'Study Designs': 'Allocation: N/A|Intervention Model: Single Group Assignment|Masking: None (Open Label)|Primary Purpose: Treatment',
#   'Other IDs': 'COVID-SARI-001',
#   'Start Date': 'January 2021',
#   'Primary Completion Date': 'January 2021',
#   'Completion Date': 'December 2021',
#   'First Posted': 'May 13, 2020',
#   'Results First Posted': nan,
#   'Last Update Posted': 'January 20, 2021',
#   'Locations': 'Divisione Clinicizzata di Malattie Infettive, ASST FBF-Sacco, Milano, MI, Italy',
#   'Study Documents': '"Study Protocol and Statistical Analysis Plan", https://ClinicalTrials.gov/ProvidedDocs/39/NCT04386239/Prot_SAP_000.pdf',
#   'URL': 'https://ClinicalTrials.gov/show/NCT04386239'},
#  {'Rank': 589,
#   'NCT Number': 'NCT04420988',
#   'Title': 'Investigational COVID-19 Convalescent Plasma Infusion for Severely or Life-threateningly Ill COVID-19 Patients',
#   'Acronym': nan,
#   'Status': 'Available',
#   'Study Results': 'No Results Available',
#   'Conditions': 'COVID-19|SARS-CoV 2|SARS-CoV Infection',
#   'Interventions': 'Biological: COVID-19 Convalescent Plasma',
#   'Outcome Measures': nan,
#   'Sponsor/Collaborators': 'Rutgers, The State University of New Jersey|University Hospital - Newark, NJ',
#   'Gender': 'All',
#   'Age': '18 Years and older \xa0 (Adult, Older Adult)',
#   'Phases': nan,
#   'Enrollment': nan,
#   'Funded Bys': 'Other',
#   'Study Type': 'Expanded Access:Individual Patients|Intermediate-size Population',
#   'Study Designs': nan,
#   'Other IDs': 'Pro2020000746, Pro2020000911',
#   'Start Date': nan,
#   'Primary Completion Date': nan,
#   'Completion Date': nan,
#   'First Posted': 'June 9, 2020',
#   'Results First Posted': nan,
#   'Last Update Posted': 'June 9, 2020',
#   'Locations': 'Rutgers New Jersey Medical School, Newark, New Jersey, United States|University Hospital, Newark, New Jersey, United States',
#   'Study Documents': '"Informed Consent Form", https://ClinicalTrials.gov/ProvidedDocs/88/NCT04420988/ICF_000.pdf',
#   'URL': 'https://ClinicalTrials.gov/show/NCT04420988'},
#  {'Rank': 615,
#   'NCT Number': 'NCT04659941',
#   'Title': 'Use of BCG Vaccine as a Preventive Measure for COVID-19 in Health Care Workers',
#   'Acronym': 'ProBCG',
#   'Status': 'Recruiting',
#   'Study Results': 'No Results Available',
#   'Conditions': 'COVID 19 Vaccine',
#   'Interventions': 'Biological: BCG vaccine',
#   'Outcome Measures': 'Compare the cumulative incidence of SARS-CoV-2 infection|Compare the cumulative incidence of severe forms of COVID-19|Assess the BCG vaccine-mediated immune response in health care workers',
#   'Sponsor/Collaborators': 'Universidade Federal do Rio de Janeiro|Ministry of Science and Technology, Brazil',
#   'Gender': 'All',
#   'Age': '18 Years and older \xa0 (Adult, Older Adult)',
#   'Phases': 'Phase 2',
#   'Enrollment': 1000.0,
#   'Funded Bys': 'Other',
#   'Study Type': 'Interventional',
#   'Study Designs': 'Allocation: Randomized|Intervention Model: Parallel Assignment|Masking: Double (Participant, Care Provider)|Primary Purpose: Prevention',
#   'Other IDs': '31942220.8.1001.5257',
#   'Start Date': 'October 1, 2020',
#   'Primary Completion Date': 'October 1, 2021',
#   'Completion Date': 'October 1, 2022',
#   'First Posted': 'December 9, 2020',
#   'Results First Posted': nan,
#   'Last Update Posted': 'December 9, 2020',
#   'Locations': 'Universidade Federal do Rio de Janeiro, Rio De Janeiro, RJ, Brazil',
#   'Study Documents': '"Study Protocol and Statistical Analysis Plan", https://ClinicalTrials.gov/ProvidedDocs/41/NCT04659941/Prot_SAP_000.pdf',
#   'URL': 'https://ClinicalTrials.gov/show/NCT04659941'},
#  {'Rank': 627,
#   'NCT Number': 'NCT04343261',
#   'Title': 'Convalescent Plasma in the Treatment of COVID 19',
#   'Acronym': nan,
#   'Status': 'Completed',
#   'Study Results': 'Has Results',
#   'Conditions': 'Severe Acute Respiratory Syndrome Coronavirus 2 (SARS-CoV-2)|COVID|Coronavirus',
#   'Interventions': 'Biological: Convalescent Plasma',
#   'Outcome Measures': 'Mortality|Viral Load|Serum Antibody Titers',
#   'Sponsor/Collaborators': 'Saint Francis Care',
#   'Gender': 'All',
#   'Age': '18 Years to 90 Years \xa0 (Adult, Older Adult)',
#   'Phases': 'Phase 2',
#   'Enrollment': 48.0,
#   'Funded Bys': 'Other',
#   'Study Type': 'Interventional',
#   'Study Designs': 'Allocation: N/A|Intervention Model: Single Group Assignment|Masking: None (Open Label)|Primary Purpose: Treatment',
#   'Other IDs': 'SFH-20-23',
#   'Start Date': 'April 10, 2020',
#   'Primary Completion Date': 'July 23, 2020',
#   'Completion Date': 'August 13, 2020',
#   'First Posted': 'April 13, 2020',
#   'Results First Posted': 'September 17, 2020',
#   'Last Update Posted': 'September 24, 2020',
#   'Locations': 'Trinity Health Of New England, Hartford, Connecticut, United States',
#   'Study Documents': '"Study Protocol and Statistical Analysis Plan", https://ClinicalTrials.gov/ProvidedDocs/61/NCT04343261/Prot_SAP_000.pdf|"Informed Consent Form: Donor Consent", https://ClinicalTrials.gov/ProvidedDocs/61/NCT04343261/ICF_001.pdf|"Informed Consent Form: Patient Consent", https://ClinicalTrials.gov/ProvidedDocs/61/NCT04343261/ICF_002.pdf',
#   'URL': 'https://ClinicalTrials.gov/show/NCT04343261'},
#  {'Rank': 638,
#   'NCT Number': 'NCT04568421',
#   'Title': 'Argentinian Registry of Patients With Rheumatic Diseases and COVID-19 Infection',
#   'Acronym': 'SAR-COVID',
#   'Status': 'Recruiting',
#   'Study Results': 'No Results Available',
#   'Conditions': 'Rheumatic Diseases',
#   'Interventions': 'Drug: Immunosuppressive Agents',
#   'Outcome Measures': 'Mortality|Hospitalization|SARS-CoV-2 infection presentation|Admission at the intensive care unit|Invasive mechanical ventilation|COVID-19 Complications|Recovery rate',
#   'Sponsor/Collaborators': 'Sociedad Argentina de Reumatologia',
#   'Gender': 'All',
#   'Age': '18 Years to 100 Years \xa0 (Adult, Older Adult)',
#   'Phases': nan,
#   'Enrollment': 3000.0,
#   'Funded Bys': 'Other',
#   'Study Type': 'Observational',
#   'Study Designs': 'Observational Model: Cohort|Time Perspective: Prospective',
#   'Other IDs': '01',
#   'Start Date': 'August 18, 2020',
#   'Primary Completion Date': 'December 31, 2021',
#   'Completion Date': 'December 31, 2021',
#   'First Posted': 'September 29, 2020',
#   'Results First Posted': nan,
#   'Last Update Posted': 'September 29, 2020',
#   'Locations': 'Sociedad Argentina de Reumatología, Ciudad Autónoma de Buenos Aires, Caba, Argentina',
#   'Study Documents': '"Study Protocol and Statistical Analysis Plan", https://ClinicalTrials.gov/ProvidedDocs/21/NCT04568421/Prot_SAP_000.pdf',
#   'URL': 'https://ClinicalTrials.gov/show/NCT04568421'},
#  {'Rank': 668,
#   'NCT Number': 'NCT04491240',
#   'Title': 'Evaluation of Safety and Efficiency of Method of Exosome Inhalation in SARS-CoV-2 Associated Pneumonia.',
#   'Acronym': 'COVID-19EXO',
#   'Status': 'Completed',
#   'Study Results': 'Has Results',
#   'Conditions': 'Covid19|SARS-CoV-2 PNEUMONIA|COVID-19',
#   'Interventions': 'Drug: EXO 1 inhalation|Drug: EXO 2 inhalation|Drug: Placebo inhalation',
#   'Outcome Measures': 'Number of Participants With Non-serious and Serious Adverse Events During Trial|Number of Participants With Non-serious and Serious Adverse During Inhalation Procedure|Time to Clinical Recovery (TTCR)|SpO2 Concentration|C-reactive Protein|Lactic Acid Dehydrogenase (LDH)',
#   'Sponsor/Collaborators': 'State-Financed Health Facility "Samara Regional Medical Center Dinasty"|Clinics of the Federal State Budgetary Educational Institution SSMU|Samara Regional Clinical Hospital V.D. Seredavin',
#   'Gender': 'All',
#   'Age': '18 Years to 65 Years \xa0 (Adult, Older Adult)',
#   'Phases': 'Phase 1|Phase 2',
#   'Enrollment': 30.0,
#   'Funded Bys': 'Other',
#   'Study Type': 'Interventional',
#   'Study Designs': 'Allocation: Randomized|Intervention Model: Parallel Assignment|Masking: Double (Participant, Care Provider)|Primary Purpose: Other',
#   'Other IDs': 'COVID-19 EXO',
#   'Start Date': 'July 20, 2020',
#   'Primary Completion Date': 'October 1, 2020',
#   'Completion Date': 'October 20, 2020',
#   'First Posted': 'July 29, 2020',
#   'Results First Posted': 'November 4, 2020',
#   'Last Update Posted': 'November 4, 2020',
#   'Locations': 'Medical Centre Dinasty, Samara, Russian Federation',
#   'Study Documents': '"Study Protocol and Statistical Analysis Plan", https://ClinicalTrials.gov/ProvidedDocs/40/NCT04491240/Prot_SAP_000.pdf',
#   'URL': 'https://ClinicalTrials.gov/show/NCT04491240'},
#  {'Rank': 687,
#   'NCT Number': 'NCT04542044',
#   'Title': 'Evaluation of the Safety and Outcomes of Outpatient Management With Mild to Moderate COVID-19 Pneumonia',
#   'Acronym': 'PneumoCoV-Ambu',
#   'Status': 'Completed',
#   'Study Results': 'No Results Available',
#   'Conditions': 'Covid19|Pneumonia',
#   'Interventions': 'Other: management strategy of outpatient with mild to moderate SARS-CoV-2 pneumonia',
#   'Outcome Measures': 'Secondary hospitalization(s) or death COVID-19 related|severity of COVID-19 disease|patient satisfaction with management strategies|Saved costs',
#   'Sponsor/Collaborators': 'University Hospital, Geneva',
#   'Gender': 'All',
#   'Age': '18 Years to 99 Years \xa0 (Adult, Older Adult)',
#   'Phases': nan,
#   'Enrollment': 40.0,
#   'Funded Bys': 'Other',
#   'Study Type': 'Observational',
#   'Study Designs': 'Observational Model: Cohort|Time Perspective: Prospective',
#   'Other IDs': 'CCER2020-01518',
#   'Start Date': 'April 2, 2020',
#   'Primary Completion Date': 'May 5, 2020',
#   'Completion Date': 'June 30, 2020',
#   'First Posted': 'September 9, 2020',
#   'Results First Posted': nan,
#   'Last Update Posted': 'September 9, 2020',
#   'Locations': 'Geneva University Hospital, Geneva, Switzerland',
#   'Study Documents': '"Study Protocol", https://ClinicalTrials.gov/ProvidedDocs/44/NCT04542044/Prot_000.pdf',
#   'URL': 'https://ClinicalTrials.gov/show/NCT04542044'},
#  {'Rank': 694,
#   'NCT Number': 'NCT04824365',
#   'Title': 'Sodium Pyruvate Nasal Spray Treatment of COVID-19 and Influenza Infections',
#   'Acronym': nan,
#   'Status': 'Recruiting',
#   'Study Results': 'No Results Available',
#   'Conditions': 'Covid19|Influenza',
#   'Interventions': 'Drug: Sodium Pyruvate|Other: Saline',
#   'Outcome Measures': 'Evaluate the ability of inhaled nasal sodium pyruvate to change COVID-19 or influenza viral titers.|Evaluate the ability of inhaled nasal sodium pyruvate to change the symptoms of COVID-19 or influenza.',
#   'Sponsor/Collaborators': 'Cellular Sciences, inc.|Missouri State University|Dynamic DNA Labs|Trinity Health Care',
#   'Gender': 'All',
#   'Age': '18 Years to 40 Years \xa0 (Adult)',
#   'Phases': 'Phase 2|Phase 3',
#   'Enrollment': 60.0,
#   'Funded Bys': 'Industry|Other',
#   'Study Type': 'Interventional',
#   'Study Designs': 'Allocation: Randomized|Intervention Model: Parallel Assignment|Masking: Triple (Participant, Care Provider, Outcomes Assessor)|Primary Purpose: Treatment',
#   'Other IDs': 'CSI-COVID-19_007',
#   'Start Date': 'April 3, 2021',
#   'Primary Completion Date': 'May 2022',
#   'Completion Date': 'June 2022',
#   'First Posted': 'April 1, 2021',
#   'Results First Posted': nan,
#   'Last Update Posted': 'April 8, 2021',
#   'Locations': 'Missouri State University, Springfield, Missouri, United States',
#   'Study Documents': '"Study Protocol and Statistical Analysis Plan", https://ClinicalTrials.gov/ProvidedDocs/65/NCT04824365/Prot_SAP_001.pdf|"Informed Consent Form", https://ClinicalTrials.gov/ProvidedDocs/65/NCT04824365/ICF_000.pdf',
#   'URL': 'https://ClinicalTrials.gov/show/NCT04824365'},
#  {'Rank': 761,
#   'NCT Number': 'NCT04323514',
#   'Title': 'Use of Ascorbic Acid in Patients With COVID 19',
#   'Acronym': nan,
#   'Status': 'Recruiting',
#   'Study Results': 'No Results Available',
#   'Conditions': 'Hospitalized Patients With Covid-19 Pneumonia',
#   'Interventions': 'Dietary Supplement: Vitamin C',
#   'Outcome Measures': 'In-hospital mortality|PCR levels|Lactate clearance|Hospital stay|Symptoms|Positive swab|Tomography imaging',
#   'Sponsor/Collaborators': 'University of Palermo',
#   'Gender': 'All',
#   'Age': 'Child, Adult, Older Adult',
#   'Phases': 'Not Applicable',
#   'Enrollment': 500.0,
#   'Funded Bys': 'Other',
#   'Study Type': 'Interventional',
#   'Study Designs': 'Allocation: N/A|Intervention Model: Single Group Assignment|Masking: None (Open Label)|Primary Purpose: Treatment',
#   'Other IDs': '3143',
#   'Start Date': 'March 13, 2020',
#   'Primary Completion Date': 'March 13, 2021',
#   'Completion Date': 'March 13, 2021',
#   'First Posted': 'March 26, 2020',
#   'Results First Posted': nan,
#   'Last Update Posted': 'March 26, 2020',
#   'Locations': 'A.R.N.A.S. Civico - Di Cristina - Benfratelli, Palermo, Italy',
#   'Study Documents': '"Study Protocol, Statistical Analysis Plan, and Informed Consent Form", https://ClinicalTrials.gov/ProvidedDocs/14/NCT04323514/Prot_SAP_ICF_000.pdf',
#   'URL': 'https://ClinicalTrials.gov/show/NCT04323514'},
#  {'Rank': 763,
#   'NCT Number': 'NCT04501822',
#   'Title': 'One-year Cardiac Follow-up of Patients With COVID-19 Pneumonia',
#   'Acronym': nan,
#   'Status': 'Recruiting',
#   'Study Results': 'No Results Available',
#   'Conditions': 'Covid19|Cardiac Complication',
#   'Interventions': 'Diagnostic Test: Evaluation of clinical, instrumental and laboratory diagnostics tests',
#   'Outcome Measures': 'Echocardiographic assessment of cardiac function|МАССЕ|Quantitative analysis of parenchymal lung damage|Functional exercises capacity assessment|Evaluation of renal function|Evaluation of inflammation|Evaluation of coagulation abnormality|Evaluation of quality of life in first year after discharge',
#   'Sponsor/Collaborators': 'Tomsk National Research Medical Center of the Russian Academy of Sciences',
#   'Gender': 'All',
#   'Age': '18 Years and older \xa0 (Adult, Older Adult)',
#   'Phases': nan,
#   'Enrollment': 380.0,
#   'Funded Bys': 'Other',
#   'Study Type': 'Observational',
#   'Study Designs': 'Observational Model: Cohort|Time Perspective: Prospective',
#   'Other IDs': 'TCRC-COVID',
#   'Start Date': 'July 19, 2020',
#   'Primary Completion Date': 'July 19, 2021',
#   'Completion Date': 'December 31, 2021',
#   'First Posted': 'August 6, 2020',
#   'Results First Posted': nan,
#   'Last Update Posted': 'August 6, 2020',
#   'Locations': 'Tyumen Cardiology Research Center, Tomsk National Research Medical Center, Russian Academy of Science, Tyumen, Russian Federation',
#   'Study Documents': '"Study Protocol", https://ClinicalTrials.gov/ProvidedDocs/22/NCT04501822/Prot_000.pdf',
#   'URL': 'https://ClinicalTrials.gov/show/NCT04501822'},
#  {'Rank': 765,
#   'NCT Number': 'NCT04716426',
#   'Title': 'APT™ T3X on the COVID-19 Contamination Rate',
#   'Acronym': nan,
#   'Status': 'Completed',
#   'Study Results': 'Has Results',
#   'Conditions': 'COVID-19',
#   'Interventions': 'Drug: Tetracycline hydrochloride 3%|Drug: Placebo',
#   'Outcome Measures': 'COVID-19 Contamination Rate.|Number of Participants With Adverse Events|Average Number of Adverse Events|Days Over Which an Adverse Event Was Reported|Other Virus or Bacteria Contamination Rate.',
#   'Sponsor/Collaborators': 'University of Nove de Julho|Santa Casa de Misericórdia de Porto Alegre',
#   'Gender': 'All',
#   'Age': '18 Years and older \xa0 (Adult, Older Adult)',
#   'Phases': 'Not Applicable',
#   'Enrollment': 100.0,
#   'Funded Bys': 'Other',
#   'Study Type': 'Interventional',
#   'Study Designs': 'Allocation: Randomized|Intervention Model: Parallel Assignment|Masking: Quadruple (Participant, Care Provider, Investigator, Outcomes Assessor)|Primary Purpose: Prevention',
#   'Other IDs': '4.485.847',
#   'Start Date': 'January 28, 2021',
#   'Primary Completion Date': 'March 25, 2021',
#   'Completion Date': 'March 25, 2021',
#   'First Posted': 'January 20, 2021',
#   'Results First Posted': 'April 8, 2021',
#   'Last Update Posted': 'April 8, 2021',
#   'Locations': 'Santa Casa de Misericórdia de Porto Alegre, Porto Alegre, Rio Grande Do Sul, Brazil',
#   'Study Documents': '"Study Protocol and Statistical Analysis Plan", https://ClinicalTrials.gov/ProvidedDocs/26/NCT04716426/Prot_SAP_000.pdf',
#   'URL': 'https://ClinicalTrials.gov/show/NCT04716426'},
#  {'Rank': 766,
#   'NCT Number': 'NCT04491994',
#   'Title': 'Clearing the Fog: Is Hydroxychloroquine Effective in Reducing COVID-19 Progression',
#   'Acronym': 'COVID-19',
#   'Status': 'Completed',
#   'Study Results': 'Has Results',
#   'Conditions': 'Covid19|Progression',
#   'Interventions': 'Drug: HCQ',
#   'Outcome Measures': 'Number of Participants With Progression|Viral Clearance',
#   'Sponsor/Collaborators': 'UNICEF|Pak Emirates Military Hospital Rawalpindi, Pakistan',
#   'Gender': 'All',
#   'Age': '18 Years to 80 Years \xa0 (Adult, Older Adult)',
#   'Phases': 'Phase 3',
#   'Enrollment': 540.0,
#   'Funded Bys': 'Other',
#   'Study Type': 'Interventional',
#   'Study Designs': 'Allocation: Randomized|Intervention Model: Parallel Assignment|Masking: None (Open Label)|Primary Purpose: Treatment',
#   'Other IDs': 'Sultan Mehmood Kamran 2',
#   'Start Date': 'April 10, 2020',
#   'Primary Completion Date': 'May 31, 2020',
#   'Completion Date': 'May 31, 2020',
#   'First Posted': 'July 30, 2020',
#   'Results First Posted': 'August 21, 2020',
#   'Last Update Posted': 'August 21, 2020',
#   'Locations': 'Pak Emirates Military Hospital, Rawalpindi, Punjab, Pakistan',
#   'Study Documents': '"Study Protocol and Statistical Analysis Plan", https://ClinicalTrials.gov/ProvidedDocs/94/NCT04491994/Prot_SAP_000.pdf',
#   'URL': 'https://ClinicalTrials.gov/show/NCT04491994'},
#  {'Rank': 784,
#   'NCT Number': 'NCT04521309',
#   'Title': 'SARS-CoV-2 Antibodies Based IVIG Therapy for COVID-19 Patients',
#   'Acronym': nan,
#   'Status': 'Completed',
#   'Study Results': 'No Results Available',
#   'Conditions': 'COVID-19',
#   'Interventions': 'Biological: SARS-CoV-2 antibody based IVIG therapy',
#   'Outcome Measures': '28 Days mortality|Requirement of supplemental oxygen support|Number of days on assisted ventilation|Days to step down|Days to Hospital Discharge|Adverse events during hospital stay|Change in C-Reactive Protein (CRP) levels|Change in neutrophil lymphocyte ratio|Change in Ferritin levels|Change in lactate dehydrogenase (LDH) levels|Change in radiological (X-ray) findings|Days to negative SARS-CoV-2 Polymerase Chain Reaction (PCR) test|Anti-SARS-CoV-2 Antibody|Change in fever|Change in Sodium levels|Change in Potassium levels|Change in Chloride levels|Change in Bicarbonate levels',
#   'Sponsor/Collaborators': 'Dow University of Health Sciences|Higher Education Commission (Pakistan)',
#   'Gender': 'All',
#   'Age': '18 Years and older \xa0 (Adult, Older Adult)',
#   'Phases': 'Phase 1|Phase 2',
#   'Enrollment': 50.0,
#   'Funded Bys': 'Other',
#   'Study Type': 'Interventional',
#   'Study Designs': 'Allocation: Randomized|Intervention Model: Sequential Assignment|Masking: Single (Participant)|Primary Purpose: Treatment',
#   'Other IDs': 'biotech001',
#   'Start Date': 'June 19, 2020',
#   'Primary Completion Date': 'January 26, 2021',
#   'Completion Date': 'February 8, 2021',
#   'First Posted': 'August 20, 2020',
#   'Results First Posted': nan,
#   'Last Update Posted': 'March 24, 2021',
#   'Locations': 'Dow University of Health Sciences, Karachi, Sindh, Pakistan',
#   'Study Documents': '"Study Protocol", https://ClinicalTrials.gov/ProvidedDocs/09/NCT04521309/Prot_001.pdf',
#   'URL': 'https://ClinicalTrials.gov/show/NCT04521309'},
#  {'Rank': 802,
#   'NCT Number': 'NCT04427098',
#   'Title': 'Enoxaparin in COVID-19 Moderate to Severe Hospitalized Patients',
#   'Acronym': 'INHIXACOV19',
#   'Status': 'Recruiting',
#   'Study Results': 'No Results Available',
#   'Conditions': 'COVID-19',
#   'Interventions': 'Drug: Enoxaparin 40 Mg/0.4 mL Injectable Solution|Drug: Enoxaparin',
#   'Outcome Measures': 'To investigate the efficacy of enoxaparin in improving the clinical outcome of hospitalized patients with moderate-severe COVID-19.|To analyse the safety of enoxaparin in hospitalized patients with moderatesevere COVID-19.|To describe the rates and the types of thromboembolic events among hospitalized patients with confirmed diagnosis of COVID-19.',
#   'Sponsor/Collaborators': 'IRCCS Azienda Ospedaliero-Universitaria di Bologna',
#   'Gender': 'All',
#   'Age': '18 Years to 90 Years \xa0 (Adult, Older Adult)',
#   'Phases': 'Phase 2',
#   'Enrollment': 300.0,
#   'Funded Bys': 'Other',
#   'Study Type': 'Interventional',
#   'Study Designs': 'Allocation: Non-Randomized|Intervention Model: Parallel Assignment|Masking: None (Open Label)|Primary Purpose: Treatment',
#   'Other IDs': '2020-001308-40',
#   'Start Date': 'May 22, 2020',
#   'Primary Completion Date': 'October 30, 2020',
#   'Completion Date': 'October 30, 2020',
#   'First Posted': 'June 11, 2020',
#   'Results First Posted': nan,
#   'Last Update Posted': 'June 17, 2020',
#   'Locations': 'Policlinico S. Orsola Malpighi Dipartimento Malattie Infettive, Bologna, Emilia Romagna, Italy|Azienda Ospedaliero-Universitaria di Parma Anestesia e Rianimazione Dipartimento di Medicina e Chirurgia, Parma, Emilia Romagna, Italy|I.R.C.C.S. "Casa Sollievo della Sofferenza", San Giovanni Rotondo (FG) UOVD Emostasi e trombosi- Poliambulatorio Giovanni Paolo II Viale Padre Pio n.7 San Giovanni Rotondo (FG), San Giovanni Rotondo, Foggia, Italy|Fondazione Poliambulanza Chirurgia Vascolare, Brescia, Italy|Piazzale Spedali Civili, 1, 25123 Brescia BS Medicina Interna UniBS 2° Medicina ASST Spedali Civili, Brescia, Italy|Azienda Ospedaliero-Universitaria "Policlinico - V. Emanuele", Catania Anestesia e Rianimazione UO Malattie Infettive, Catania, Italy|ASST Cremona Unità Operativa di Chirurgia Vascolare Dipartimento di Medicina di Laboratorio e di Radiologia- Centro Emostasi e Trombosi, Cremona, Italy|Ospedale Morgagni Pierantoni U.O.C. Malattie Infettive, Forlì, Italy|Ospedale Carlo Poma di Mantova MALATTIE INFETTIVE Padiglione 37 Str. Lago Paiolo, 10, 46100 Mantova, Mantova, Italy|AZIENDA OSPEDALIERA Regionale S CARLO POTENZA Struttura Complessa Interaziendale "Malattie Infettive", Matera, Italy|Ospedale San Raffaele Unità Funzionale dell\'Unità Operativa di Malattie Infettive Osp. San Raffaele, Milano, Italy|Ospedale Amedeo di Savoia Torino Università di Torino Malattie Infettive, Torino, Italy|Azienda Ospedaliera Universitaria Integrata Verona UOC Malattie Infettive e Tropicali, Verona, Italy',
#   'Study Documents': '"Study Protocol and Statistical Analysis Plan", https://ClinicalTrials.gov/ProvidedDocs/98/NCT04427098/Prot_SAP_000.pdf',
#   'URL': 'https://ClinicalTrials.gov/show/NCT04427098'},
#  {'Rank': 837,
#   'NCT Number': 'NCT04523831',
#   'Title': 'Clinical Trial of Ivermectin Plus Doxycycline for the Treatment of Confirmed Covid-19 Infection',
#   'Acronym': nan,
#   'Status': 'Completed',
#   'Study Results': 'Has Results',
#   'Conditions': 'Covid19',
#   'Interventions': 'Drug: Ivermectin and Doxycycline|Drug: Standard of care',
#   'Outcome Measures': 'Number of Patients With Early Clinical Improvement|Number of Participants With Late Clinical Recovery|Number of Patients Having Clinical Deterioration.|Number of Patients Remain Persistently Positive for RT-PCR of Covid-19',
#   'Sponsor/Collaborators': 'Dhaka Medical College',
#   'Gender': 'All',
#   'Age': '18 Years and older \xa0 (Adult, Older Adult)',
#   'Phases': 'Phase 3',
#   'Enrollment': 400.0,
#   'Funded Bys': 'Other',
#   'Study Type': 'Interventional',
#   'Study Designs': 'Allocation: Randomized|Intervention Model: Parallel Assignment|Masking: Double (Participant, Investigator)|Primary Purpose: Treatment',
#   'Other IDs': 'ERC-DMC/ECC/2020/117',
#   'Start Date': 'June 1, 2020',
#   'Primary Completion Date': 'August 22, 2020',
#   'Completion Date': 'September 10, 2020',
#   'First Posted': 'August 24, 2020',
#   'Results First Posted': 'October 9, 2020',
#   'Last Update Posted': 'October 9, 2020',
#   'Locations': 'Dhaka Medical College, Dhaka, Bangladesh',
#   'Study Documents': '"Study Protocol and Informed Consent Form", https://ClinicalTrials.gov/ProvidedDocs/31/NCT04523831/Prot_ICF_000.pdf|"Statistical Analysis Plan", https://ClinicalTrials.gov/ProvidedDocs/31/NCT04523831/SAP_001.pdf',
#   'URL': 'https://ClinicalTrials.gov/show/NCT04523831'},
#  {'Rank': 930,
#   'NCT Number': 'NCT04783025',
#   'Title': 'A Blended Gaming COVID-19 Training System (BGCTS) With WHO Guidelines for Staff in Residential Care Homes',
#   'Acronym': 'BGCTS',
#   'Status': 'Not yet recruiting',
#   'Study Results': 'No Results Available',
#   'Conditions': 'Infection Control|COVID-19',
#   'Interventions': 'Behavioral: Blended Gaming COVID-19 Training System (BGCTS)|Behavioral: Usual care, infection control briefing',
#   'Outcome Measures': 'Changes in unobtrusive observational-based compliance rate of infection control practices|Knowledge and attitudes towards respiratory infection (KARI)|Self-reported Infection Control Practice (SICP)|Demographic data|Data on experience',
#   'Sponsor/Collaborators': 'The Hong Kong Polytechnic University',
#   'Gender': 'All',
#   'Age': '18 Years to 65 Years \xa0 (Adult, Older Adult)',
#   'Phases': 'Not Applicable',
#   'Enrollment': 188.0,
#   'Funded Bys': 'Other',
#   'Study Type': 'Interventional',
#   'Study Designs': 'Allocation: Randomized|Intervention Model: Parallel Assignment|Masking: Single (Outcomes Assessor)|Primary Purpose: Health Services Research',
#   'Other IDs': 'HSEARS20200903007',
#   'Start Date': 'March 1, 2021',
#   'Primary Completion Date': 'December 31, 2021',
#   'Completion Date': 'March 1, 2022',
#   'First Posted': 'March 4, 2021',
#   'Results First Posted': nan,
#   'Last Update Posted': 'March 4, 2021',
#   'Locations': 'The Hong Kong Polytechnic University, Hong Kong, Hong Kong',
#   'Study Documents': '"Informed Consent Form", https://ClinicalTrials.gov/ProvidedDocs/25/NCT04783025/ICF_000.pdf',
#   'URL': 'https://ClinicalTrials.gov/show/NCT04783025'},
#  {'Rank': 1017,
#   'NCT Number': 'NCT04367207',
#   'Title': 'African Covid-19 Critical Care Outcomes Study',
#   'Acronym': nan,
#   'Status': 'Recruiting',
#   'Study Results': 'No Results Available',
#   'Conditions': 'Severe Acute Respiratory Syndrome Coronavirus 2',
#   'Interventions': nan,
#   'Outcome Measures': 'In-hospital mortality|Risk factors (resources, comorbidities and interventions) associated with mortality',
#   'Sponsor/Collaborators': 'University of Cape Town|University of KwaZulu',
#   'Gender': 'All',
#   'Age': '18 Years and older \xa0 (Adult, Older Adult)',
#   'Phases': nan,
#   'Enrollment': 2000.0,
#   'Funded Bys': 'Other',
#   'Study Type': 'Observational',
#   'Study Designs': 'Observational Model: Cohort|Time Perspective: Prospective',
#   'Other IDs': 'ACCCOS',
#   'Start Date': 'May 1, 2020',
#   'Primary Completion Date': 'December 1, 2020',
#   'Completion Date': 'December 31, 2020',
#   'First Posted': 'April 29, 2020',
#   'Results First Posted': nan,
#   'Last Update Posted': 'September 10, 2020',
#   'Locations': 'Groote Schuur Hospital, Cape Town, Western Cape, South Africa',
#   'Study Documents': '"Study Protocol and Statistical Analysis Plan", https://ClinicalTrials.gov/ProvidedDocs/07/NCT04367207/Prot_SAP_000.pdf',
#   'URL': 'https://ClinicalTrials.gov/show/NCT04367207'},
#  {'Rank': 1085,
#   'NCT Number': 'NCT04456413',
#   'Title': 'Convalescent Plasma as Treatment for Subjects With Early COVID-19 Infection',
#   'Acronym': nan,
#   'Status': 'Recruiting',
#   'Study Results': 'No Results Available',
#   'Conditions': 'COVID-19',
# ...
#   'Study Results': 'Has Results',
#   'Conditions': 'HIV-1 Infection',
#   'Interventions': 'Drug: Etoposide (ET)|Drug: Bleomycin and Vincristine (BV)|Drug: Paclitaxel (PTX)|Drug: Co-formulated Efavirenz/Emtricitabine/Tenofovir Disoproxil Fumarate (EFV/FTC/TDF)',
#   'Outcome Measures': "Cumulative Rate of Progression-Free Survival by Week 48 for ET+ART vs. PTX+ART|Cumulative Rate of Progression-Free Survival by Week 48 for BV+ART vs. PTX+ART|Cumulative Rate of Death by Week 48 for ET+ART vs. PTX+ART|Cumulative Rate of Death by Week 48 for BV+ART vs. PTX+ART|Cumulative Rate of IERC-confirmed KS Progression by Week 48 for ET+ART vs. PTX+ART|Cumulative Rate of IERC-confirmed KS Progression by Week 48 for BV+ART vs. PTX+ART|Cumulative Rate of AIDS-defining Event by Week 48 for ET+ART vs. PTX+ART|Cumulative Rate of AIDS-defining Event by Week 48 for BV+ART vs. PTX+ART|Cumulative Rate of HIV-1 RNA Virologic Failure by Week 48 for ET+ART vs. PTX+ART|Cumulative Rate of HIV-1 RNA Virologic Failure by Week 48 for BV+ART vs. PTX+ART|Number of Participants With Kaposi's Sarcoma-Immune Reconstitution Inflammatory Syndrome (KS-IRIS) for ET+ART vs. PTX+ART|Number of Participants With Kaposi's Sarcoma-Immune Reconstitution Inflammatory Syndrome (KS-IRIS) for BV+ART vs. PTX+ART|Cumulative Rate of KS Progression, Death, or AIDS Defining Event by Week 48 for ET+ART vs. PTX+ART|Cumulative Rate of KS Progression, Death, or AIDS Defining Event by Week 48 for BV+ART vs. PTX+ART|Cumulative Rate of KS Progression, Death, AIDS Defining Event, or Virologic Failure by Week 48 for ET+ART vs. PTX+ART|Cumulative Rate of KS Progression, Death, AIDS Defining Event, or Virologic Failure by Week 48 for BV+ART vs. PTX+ART|Cumulative Rate of KS Progression, Death, AIDS Defining Event, Virologic Failure, or KS-IRIS by Week 48 for ET+ART vs. PTX+ART|Cumulative Rate of KS Progression, Death, AIDS Defining Event, Virologic Failure, or KS-IRIS by Week 48 for BV+ART vs. PTX+ART|Cumulative Rate of Change in KS Treatment by Week 48 for ET+ART vs. PTX+ART|Cumulative Rate of Change in KS Treatment by Week 48 for BV+ART vs. PTX+ART|Cumulative Rate of Death for ET+ART vs. PTX+ART|Cumulative Rate of Death for BV+ART vs PTX+ART|Time to IERC-confirmed KS Progression or Death for ET+ART vs. PTX+ART|Time to IERC-confirmed KS Progression or Death for BV+ART vs. PTX+ART|Number of Participants With Objective Response for ET+ART vs. PTX+ART|Number of Participants With Objective Response for BV+ART vs. PTX+ART|Duration of Objective Response for ET+ART vs. PTX+ART|Duration of Objective Response for BV+ART vs. PTX+ART|Number of Participants With Symptomatic Peripheral Neuropathy (SPN)|Number of Participants With Peripheral Neuropathy (PN)|Number of Participants With Treatment-related Toxicities and Adverse Events (AEs)|Changes in CD4+ Lymphocyte Cell Count for ET+ART vs. PTX+ART|Changes in CD4+ Lymphocyte Cell Count for BV+ART vs. PTX+ART|Self-reported Adherence to ART Therapy|Presence of Oral KS|Salivary KSHV|Quality of Life Measures|Immunohistochemical Evaluations of Viral and Cellular Gene Expression.|Plasma KS-associated Herpesvirus (KSHV)|Peripheral Blood Mononuclear Cell (PBMC) KSHV|RNA Levels for KSHV Genes|Cellular and Humoral Markers of Immune Function and Activation|Number of Participants With IERC-Confirmed KS Disease Progression, Dose-Limiting Toxicity, Death, AIDS-Defining Events, Virologic Failure and Objective Response in Step 2|Number of Participants With IERC-Confirmed KS Disease Progression, Dose-Limiting Toxicity, Death, AIDS-Defining Events, Virologic Failure and Objective Response in Step 3|Number of Participants With IERC-Confirmed KS Disease Progression, Dose-Limiting Toxicity, Death, AIDS-Defining Events, Virologic Failure and Objective Response in Step 4",
#   'Sponsor/Collaborators': 'AIDS Clinical Trials Group|National Institute of Allergy and Infectious Diseases (NIAID)|National Cancer Institute (NCI)|National Institute of Dental and Craniofacial Research (NIDCR)|AIDS Malignancy Consortium',
#   'Gender': 'All',
#   'Age': '18 Years and older \xa0 (Adult, Older Adult)',
#   'Phases': 'Phase 3',
#   'Enrollment': 334.0,
#   'Funded Bys': 'Other|NIH',
#   'Study Type': 'Interventional',
#   'Study Designs': 'Allocation: Randomized|Intervention Model: Parallel Assignment|Masking: None (Open Label)|Primary Purpose: Treatment',
#   'Other IDs': 'ACTG A5263/AMC 066|1U01AI068636|U01CA121947',
#   'Start Date': 'October 1, 2013',
#   'Primary Completion Date': 'March 13, 2018',
#   'Completion Date': 'August 29, 2019',
#   'First Posted': 'September 15, 2011',
#   'Results First Posted': 'April 8, 2019',
#   'Last Update Posted': 'November 23, 2020',
#   'Locations': 'Instituto de Pesquisa Clinica Evandro Chagas (12101), Rio de Janeiro, Brazil|Moi University International Clnical Trials Unit, Eldoret, Kenya|KMRI / Walter Reed Project Clinical Research Center, Kericho, Kenya|Kenya Medical Research Institute/Center for Disease Control (KEMRI/CDC) CRS (31460), Kisumu, Kenya|Univ. of Malawi, John Hopkins Project, Blantyre, Malawi|Malawi CRS (12001), Lilongwe, Malawi|Family Clinical Research Unit (FAM-CUR) CRS (8950), Cape Town, West Cape, South Africa|Durban Adult HIV CRS (11201), Durban, South Africa|University of Witwatersrand, Johannesburg, South Africa|Uganda Cancer Institute ACTG CRS, Kampala, Uganda|UZ-Parirenyatwa CRS (30313), Harare, Zimbabwe',
#   'Study Documents': '"Study Protocol and Informed Consent Form", https://ClinicalTrials.gov/ProvidedDocs/18/NCT01435018/Prot_ICF_000.pdf|"Statistical Analysis Plan", https://ClinicalTrials.gov/ProvidedDocs/18/NCT01435018/SAP_001.pdf',
#   'URL': 'https://ClinicalTrials.gov/show/NCT01435018'},
#  {'Rank': 5738,
#   'NCT Number': 'NCT03483935',
#   'Title': 'Microwave Therapy for Treatment of Precancerous Actinic Keratoses',
#   'Acronym': 'MTAK',
#   'Status': 'Completed',
#   'Study Results': 'Has Results',
#   'Conditions': 'Actinic Keratoses|Precancerous Skin Lesion',
#   'Interventions': 'Other: Microwave treatment',
#   'Outcome Measures': 'Resolution of AK Lesions Following Microwave Treatment|Complete Resolution of AKs Following Microwave Treatment|Partial Resolution of AKs Following Microwave Treatment|Level of Pain Experienced During Treatment|Duration of Pain Post Treatment|Change in Ki67 Staining Determined Immunohistochemically by the Use of Specific Antibodies on Fixed Material|Change in Hematoxylin and Eosin Stain|Change in Apoptotic Cells Determined Using the ApopTag Peroxidase Detection Kit|Change in Gene Activity Determined by ApopTag Peroxidase',
#   'Sponsor/Collaborators': 'University of Dundee|Emblation Limited',
#   'Gender': 'All',
#   'Age': '18 Years and older \xa0 (Adult, Older Adult)',
#   'Phases': 'Not Applicable',
#   'Enrollment': 18.0,
#   'Funded Bys': 'Other',
#   'Study Type': 'Interventional',
#   'Study Designs': 'Allocation: Randomized|Intervention Model: Parallel Assignment|Masking: None (Open Label)|Primary Purpose: Treatment',
#   'Other IDs': '2016DS12',
#   'Start Date': 'March 7, 2018',
#   'Primary Completion Date': 'February 28, 2019',
#   'Completion Date': 'February 28, 2019',
#   'First Posted': 'March 30, 2018',
#   'Results First Posted': 'February 23, 2021',
#   'Last Update Posted': 'February 23, 2021',
#   'Locations': 'NHS Tayside, Dundee, United Kingdom',
#   'Study Documents': '"Study Protocol", https://ClinicalTrials.gov/ProvidedDocs/35/NCT03483935/Prot_001.pdf|"Statistical Analysis Plan", https://ClinicalTrials.gov/ProvidedDocs/35/NCT03483935/SAP_002.pdf',
#   'URL': 'https://ClinicalTrials.gov/show/NCT03483935'},
#  {'Rank': 5744,
#   'NCT Number': 'NCT03102034',
#   'Title': 'Evaluating the Infectivity, Safety, and Immunogenicity of a Single Dose of a Recombinant Live-Attenuated Respiratory Syncytial Virus Vaccine (D46/NS2/N/ΔM2-2-HindIII) in RSV-Seronegative Infants 6 to 24 Months of Age',
#   'Acronym': nan,
#   'Status': 'Completed',
#   'Study Results': 'Has Results',
#   'Conditions': 'Respiratory Syncytial Virus Infections',
#   'Interventions': 'Biological: D46/NS2/N/ΔM2-2-HindIII|Biological: Placebo',
#   'Outcome Measures': 'Number of Participants With Solicited Adverse Events (AEs) by Grade|Number of Participants With Unsolicited AEs by Grade|Number of Participants With Serious Adverse Events (SAEs)|Number of Participants Infected With RSV Vaccine Virus|Peak Titer of Vaccine Virus Shed|Duration of Vaccine Virus Shedding in Nasal Washes|Number of Participants With a Greater Than or Equal to 4-fold Rise in Serum RSV-neutralizing Antibody Titer|Serum Antibody Responses to RSV F Glycoprotein as Assessed by Enzyme-linked Immunosorbent Assay (ELISA)|Number of Participants Who Had Symptomatic, Medically Attended Respiratory and Febrile Illness, Among Those Who Experienced Natural Infection With wt RSV During the Subsequent RSV Season|Magnitude of Serum RSV-neutralizing Antibody Responses in the Vaccine and Placebo Recipients Who Experienced Natural Infection With wt RSV During the Subsequent RSV Season.|Number of Participants With B Cell Responses to Vaccine|Frequency of Mucosal Antibody Responses to Vaccine',
#   'Sponsor/Collaborators': 'National Institute of Allergy and Infectious Diseases (NIAID)',
#   'Gender': 'All',
#   'Age': '6 Months to 24 Months \xa0 (Child)',
#   'Phases': 'Phase 1',
#   'Enrollment': 32.0,
#   'Funded Bys': 'NIH',
#   'Study Type': 'Interventional',
#   'Study Designs': 'Allocation: Randomized|Intervention Model: Parallel Assignment|Masking: Quadruple (Participant, Care Provider, Investigator, Outcomes Assessor)|Primary Purpose: Prevention',
#   'Other IDs': 'IMPAACT 2013|30074',
#   'Start Date': 'April 6, 2017',
#   'Primary Completion Date': 'May 25, 2018',
#   'Completion Date': 'May 25, 2018',
#   'First Posted': 'April 5, 2017',
#   'Results First Posted': 'June 14, 2019',
#   'Last Update Posted': 'December 30, 2020',
#   'Locations': "Usc La Nichd Crs, Los Angeles, California, United States|David Geffen School of Medicine at UCLA NICHD CRS, Los Angeles, California, United States|Univ. of Colorado Denver NICHD CRS, Aurora, Colorado, United States|Emory University School of Medicine NICHD CRS, Atlanta, Georgia, United States|Rush Univ. Cook County Hosp. Chicago NICHD CRS, Chicago, Illinois, United States|Lurie Children's Hospital of Chicago (LCH) CRS, Chicago, Illinois, United States|Johns Hopkins University Center for Immunization Research, Baltimore, Maryland, United States|Jacobi Med. Ctr. Bronx NICHD CRS, Bronx, New York, United States|SUNY Stony Brook NICHD CRS, Stony Brook, New York, United States|St. Jude Children's Research Hospital CRS, Memphis, Tennessee, United States",
#   'Study Documents': '"Statistical Analysis Plan", https://ClinicalTrials.gov/ProvidedDocs/34/NCT03102034/SAP_000.pdf|"Study Protocol", https://ClinicalTrials.gov/ProvidedDocs/34/NCT03102034/Prot_001.pdf',
#   'URL': 'https://ClinicalTrials.gov/show/NCT03102034'},
#  {'Rank': 5766,
#   'NCT Number': 'NCT04429061',
#   'Title': 'Reaching 90 90 90 in Adolescents in Zambia: Using All Our SKILLZ',
#   'Acronym': 'SKILLZ',
#   'Status': 'Recruiting',
#   'Study Results': 'No Results Available',
#   'Conditions': 'HIV Infections|Pregnancy Related|STI|Mental Health Wellness 1',
#   'Interventions': 'Behavioral: SKILLZ-Girl Enhanced football curriculum',
#   'Outcome Measures': 'Number of participants undergoing HIV testing within 24 months|Number of participants accessing SRH related prevention services within 24 months|The percentage of HIV infected participants being virally suppressed at 12 months|The percentage of HIV infected participants retained in care at 3 months|The percentage of HIV infected participants retained in care at 6 months|The percentage of HIV infected participants retained in care at 12 months|Conduct a process evaluation to describe how the intervention worked|Average short-term costs for the program implementation based on net-costs for the intervention.|Fidelity monitoring or adherence to the program as measured by the number of coaching sessions conducted per plan.|Identify barriers that prevent intervention participation',
#   'Sponsor/Collaborators': 'University of Alabama at Birmingham|University of California, San Francisco|Centre for Infectious Disease Research in Zambia|Grassroot Soccer (GRS)|Washington University School of Medicine',
#   'Gender': 'Female',
#   'Age': '16 Years and older \xa0 (Child, Adult, Older Adult)',
#   'Phases': 'Not Applicable',
#   'Enrollment': 3200.0,
#   'Funded Bys': 'Other',
#   'Study Type': 'Interventional',
#   'Study Designs': 'Allocation: Randomized|Intervention Model: Parallel Assignment|Masking: None (Open Label)|Primary Purpose: Supportive Care',
#   'Other IDs': 'IRB-300002251',
#   'Start Date': 'March 1, 2020',
#   'Primary Completion Date': 'March 30, 2023',
#   'Completion Date': 'June 30, 2023',
#   'First Posted': 'June 11, 2020',
#   'Results First Posted': nan,
#   'Last Update Posted': 'June 11, 2020',
#   'Locations': 'Centre of Infectious Disease Research Zambia, Lusaka, Zambia',
#   'Study Documents': '"Study Protocol and Statistical Analysis Plan", https://ClinicalTrials.gov/ProvidedDocs/61/NCT04429061/Prot_SAP_000.pdf',
#   'URL': 'https://ClinicalTrials.gov/show/NCT04429061'},
#  {'Rank': 5771,
#   'NCT Number': 'NCT03392883',
#   'Title': 'Scaling Up Science-based Mental Health Interventions in Latin America',
#   'Acronym': 'DIADA',
#   'Status': 'Active, not recruiting',
#   'Study Results': 'No Results Available',
#   'Conditions': 'Depression|Problematic Alcohol Use',
#   'Interventions': 'Behavioral: Laddr',
#   'Outcome Measures': 'The Integrated Measure of Implementation Context and Outcomes as a Change Over Time in Low and Middle Income Countries Consumer Instrument|The Integrated Measure of Implementation Context and Outcomes as a Change Over Time in Low and Middle Income Countries Provider Instrument|The Integrated Measure of Implementation Context and Outcomes as a Change Over Time in Low and Middle Income Countries Organizational Staff Instrument|The Program Sustainability Assessment Tool (PSAT) Providers|The Program Sustainability Assessment Tool (PSAT) Administrative Staff|Patient Health Questionnaire (PHQ-8)|Alcohol Timeline Follow-back (Alcohol TLFB) (only for pilot participants)|12-item World Health Organization Disability Assessment Schedule 2.0 (WHODAS)|EuroQOL Five Dimensions Questionnaire (EQ-5D) (only for pilot participants)|General Anxiety Disorder screener (GAD-7)|EuroQol Visual Analogue Scale (EQ-VAS) (only for pilot participants)|The Quick Drinking Screen (QDS) (for full implementation study only)',
#   'Sponsor/Collaborators': 'Dartmouth-Hitchcock Medical Center|Pontificia Universidad Javeriana|National Institute of Mental Health (NIMH)',
#   'Gender': 'All',
#   'Age': '18 Years and older \xa0 (Adult, Older Adult)',
#   'Phases': 'Not Applicable',
#   'Enrollment': 3091.0,
#   'Funded Bys': 'Other|NIH',
#   'Study Type': 'Interventional',
#   'Study Designs': 'Allocation: N/A|Intervention Model: Single Group Assignment|Masking: None (Open Label)|Primary Purpose: Health Services Research',
#   'Other IDs': '1U19MH109988 D18019|1U19MH109988',
#   'Start Date': 'February 13, 2018',
#   'Primary Completion Date': 'April 2021',
#   'Completion Date': 'April 2021',
#   'First Posted': 'January 8, 2018',
#   'Results First Posted': nan,
#   'Last Update Posted': 'December 19, 2020',
#   'Locations': 'Salud de Tundama, Duitama, Boyaca, Colombia|Empresa Social del Estado Hospital Regional de Duitama- Santa Rosa de Viterbo Branch, Santa Rosa de Viterbo, Boyaca, Colombia|ESE Hospital San Antonio de Guatavita, Guatavita, Cundinamarca, Colombia|Hospital Mario Gaitán Yanguas, Soacha, Cundinamarca, Colombia|Empresa Social del Estado Hospital Nelson Restrepo Martinez, Guayabal, Tolima, Colombia|Javesalud, Bogotá, Colombia',
#   'Study Documents': '"Informed Consent Form: Patient Informed Consent form", https://ClinicalTrials.gov/ProvidedDocs/83/NCT03392883/ICF_000.pdf|"Informed Consent Form: Staff Informed Consent form", https://ClinicalTrials.gov/ProvidedDocs/83/NCT03392883/ICF_001.pdf',
#   'URL': 'https://ClinicalTrials.gov/show/NCT03392883'}]

# %%
## load the eligibility criteria for clinical trial data set from file to dataframe for analysis
df_PatintEC = pd.read_csv('./data/Bells_Palsy_Clinical_Trial.csv')
df_PatintEC.head()
# Out:
#    Patient ID     Sex  Age  Baseline Score on House–Brackmann scale  \
# 0           1  Female   77                                        6
# 1           2  Female   61                                        6
# 2           3  Female   46                                        4
# 3           4  Female   46                                        3
# 4           5  Female   42                                        3
#
#   Time between onset of symptoms and start of treatment       Treatment Group  \
# 0                                       Within 24 hr     Prednisolone–Placebo
# 1                                       Within 24 hr     Prednisolone–Placebo
# 2                                      >24 to ≤48 hr     Prednisolone–Placebo
# 3                                       Within 24 hr     Prednisolone–Placebo
# 4                                      >24 to ≤48 hr     Prednisolone–Placebo
#
#   Received Prednisolone Received Acyclovir  \
# 0                   Yes                 No
# 1                   Yes                 No
# 2                   Yes                 No
# 3                   Yes                 No
# 4                   Yes                 No
#
#    3-Month Score on House–Brackmann scale Full Recovery in 3 Months  \
# 0                                       2                        No
# 1                                       1                       Yes
# 2                                       1                       Yes
# 3                                       1                       Yes
# 4                                       1                       Yes
#
#    9-Month Score on House–Brackmann scale Full Recovery in 9 Months
# 0                                       2                        No
# 1                                       1                       Yes
# 2                                       1                       Yes
# 3                                       1                       Yes
# 4                                       1                       Yes

# %%
df_PatintEC.describe()
# Out:
#        Patient ID         Age  Baseline Score on House–Brackmann scale  \
# count  494.000000  494.000000                               494.000000
# mean   247.500000   44.868421                                 3.680162
# std    142.749781   14.550357                                 1.131752
# min      1.000000   16.000000                                 2.000000
# 25%    124.250000   34.000000                                 3.000000
# 50%    247.500000   44.000000                                 4.000000
# 75%    370.750000   55.000000                                 4.000000
# max    494.000000   90.000000                                 6.000000
#
#        3-Month Score on House–Brackmann scale  \
# count                              494.000000
# mean                                 1.340081
# std                                  0.609037
# min                                  1.000000
# 25%                                  1.000000
# 50%                                  1.000000
# 75%                                  2.000000
# max                                  4.000000
#
#        9-Month Score on House–Brackmann scale
# count                              494.000000
# mean                                 1.143725
# std                                  0.461050
# min                                  1.000000
# 25%                                  1.000000
# 50%                                  1.000000
# 75%                                  1.000000
# max                                  4.000000

# %%
## Convert dataframe to dictionary as a preparation to create the embedding (vectorised data). 
## The data is stored in key-value format
df_PatintEC.to_dict('records')
# Out:
# [{'Patient ID': 1,
#   'Sex': 'Female',
#   'Age': 77,
#   'Baseline Score on House–Brackmann scale': 6,
#   'Time between onset of symptoms and start of treatment': 'Within 24 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 2,
#   'Full Recovery in 3 Months': 'No',
#   '9-Month Score on House–Brackmann scale': 2,
#   'Full Recovery in 9 Months': 'No'},
#  {'Patient ID': 2,
#   'Sex': 'Female',
#   'Age': 61,
#   'Baseline Score on House–Brackmann scale': 6,
#   'Time between onset of symptoms and start of treatment': 'Within 24 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 3,
#   'Sex': 'Female',
#   'Age': 46,
#   'Baseline Score on House–Brackmann scale': 4,
#   'Time between onset of symptoms and start of treatment': '>24 to ≤48 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 4,
#   'Sex': 'Female',
#   'Age': 46,
#   'Baseline Score on House–Brackmann scale': 3,
#   'Time between onset of symptoms and start of treatment': 'Within 24 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 5,
#   'Sex': 'Female',
#   'Age': 42,
#   'Baseline Score on House–Brackmann scale': 3,
#   'Time between onset of symptoms and start of treatment': '>24 to ≤48 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 6,
#   'Sex': 'Female',
#   'Age': 50,
#   'Baseline Score on House–Brackmann scale': 4,
#   'Time between onset of symptoms and start of treatment': '>48 to ≤72 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 7,
#   'Sex': 'Male',
#   'Age': 37,
#   'Baseline Score on House–Brackmann scale': 4,
#   'Time between onset of symptoms and start of treatment': '>24 to ≤48 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 8,
#   'Sex': 'Female',
#   'Age': 28,
#   'Baseline Score on House–Brackmann scale': 4,
#   'Time between onset of symptoms and start of treatment': '>24 to ≤48 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 9,
#   'Sex': 'Female',
#   'Age': 41,
#   'Baseline Score on House–Brackmann scale': 4,
#   'Time between onset of symptoms and start of treatment': '>24 to ≤48 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 10,
#   'Sex': 'Male',
#   'Age': 36,
#   'Baseline Score on House–Brackmann scale': 4,
#   'Time between onset of symptoms and start of treatment': 'Within 24 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 11,
#   'Sex': 'Female',
#   'Age': 41,
#   'Baseline Score on House–Brackmann scale': 4,
#   'Time between onset of symptoms and start of treatment': 'Within 24 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 12,
#   'Sex': 'Male',
#   'Age': 18,
#   'Baseline Score on House–Brackmann scale': 2,
#   'Time between onset of symptoms and start of treatment': '>24 to ≤48 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 13,
#   'Sex': 'Female',
#   'Age': 30,
#   'Baseline Score on House–Brackmann scale': 3,
#   'Time between onset of symptoms and start of treatment': 'Within 24 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 14,
#   'Sex': 'Male',
#   'Age': 34,
#   'Baseline Score on House–Brackmann scale': 4,
#   'Time between onset of symptoms and start of treatment': '>24 to ≤48 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 15,
#   'Sex': 'Male',
#   'Age': 52,
#   'Baseline Score on House–Brackmann scale': 4,
#   'Time between onset of symptoms and start of treatment': '>24 to ≤48 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 16,
#   'Sex': 'Male',
#   'Age': 32,
#   'Baseline Score on House–Brackmann scale': 4,
#   'Time between onset of symptoms and start of treatment': 'Within 24 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 17,
#   'Sex': 'Male',
#   'Age': 55,
#   'Baseline Score on House–Brackmann scale': 2,
#   'Time between onset of symptoms and start of treatment': '>48 to ≤72 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 18,
#   'Sex': 'Female',
#   'Age': 43,
#   'Baseline Score on House–Brackmann scale': 3,
#   'Time between onset of symptoms and start of treatment': '>24 to ≤48 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 19,
#   'Sex': 'Female',
#   'Age': 33,
#   'Baseline Score on House–Brackmann scale': 4,
#   'Time between onset of symptoms and start of treatment': '>48 to ≤72 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 20,
#   'Sex': 'Female',
#   'Age': 37,
#   'Baseline Score on House–Brackmann scale': 2,
#   'Time between onset of symptoms and start of treatment': '>24 to ≤48 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 21,
#   'Sex': 'Male',
#   'Age': 32,
#   'Baseline Score on House–Brackmann scale': 3,
#   'Time between onset of symptoms and start of treatment': '>24 to ≤48 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 22,
#   'Sex': 'Male',
#   'Age': 37,
#   'Baseline Score on House–Brackmann scale': 4,
#   'Time between onset of symptoms and start of treatment': 'Within 24 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 23,
#   'Sex': 'Female',
#   'Age': 32,
#   'Baseline Score on House–Brackmann scale': 2,
#   'Time between onset of symptoms and start of treatment': '>48 to ≤72 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 24,
#   'Sex': 'Female',
#   'Age': 61,
#   'Baseline Score on House–Brackmann scale': 4,
#   'Time between onset of symptoms and start of treatment': 'Within 24 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 2,
#   'Full Recovery in 3 Months': 'No',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 25,
#   'Sex': 'Male',
#   'Age': 63,
#   'Baseline Score on House–Brackmann scale': 4,
#   'Time between onset of symptoms and start of treatment': 'Within 24 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 26,
#   'Sex': 'Male',
#   'Age': 64,
#   'Baseline Score on House–Brackmann scale': 3,
#   'Time between onset of symptoms and start of treatment': '>24 to ≤48 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 27,
#   'Sex': 'Female',
#   'Age': 47,
#   'Baseline Score on House–Brackmann scale': 4,
#   'Time between onset of symptoms and start of treatment': '>24 to ≤48 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 28,
#   'Sex': 'Male',
#   'Age': 68,
#   'Baseline Score on House–Brackmann scale': 5,
#   'Time between onset of symptoms and start of treatment': 'Within 24 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 29,
#   'Sex': 'Female',
#   'Age': 36,
#   'Baseline Score on House–Brackmann scale': 2,
#   'Time between onset of symptoms and start of treatment': '>48 to ≤72 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 30,
#   'Sex': 'Female',
#   'Age': 45,
#   'Baseline Score on House–Brackmann scale': 3,
#   'Time between onset of symptoms and start of treatment': '>24 to ≤48 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 31,
#   'Sex': 'Male',
#   'Age': 36,
#   'Baseline Score on House–Brackmann scale': 4,
#   'Time between onset of symptoms and start of treatment': 'Within 24 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 32,
#   'Sex': 'Female',
#   'Age': 35,
#   'Baseline Score on House–Brackmann scale': 3,
#   'Time between onset of symptoms and start of treatment': 'Within 24 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 33,
#   'Sex': 'Male',
#   'Age': 58,
#   'Baseline Score on House–Brackmann scale': 3,
#   'Time between onset of symptoms and start of treatment': '>48 to ≤72 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 2,
#   'Full Recovery in 3 Months': 'No',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 34,
#   'Sex': 'Male',
#   'Age': 68,
#   'Baseline Score on House–Brackmann scale': 2,
#   'Time between onset of symptoms and start of treatment': '>24 to ≤48 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 35,
#   'Sex': 'Male',
#   'Age': 24,
#   'Baseline Score on House–Brackmann scale': 5,
#   'Time between onset of symptoms and start of treatment': '>24 to ≤48 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 36,
#   'Sex': 'Male',
#   'Age': 53,
#   'Baseline Score on House–Brackmann scale': 3,
#   'Time between onset of symptoms and start of treatment': '>24 to ≤48 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 2,
#   'Full Recovery in 3 Months': 'No',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 37,
#   'Sex': 'Female',
#   'Age': 69,
#   'Baseline Score on House–Brackmann scale': 2,
#   'Time between onset of symptoms and start of treatment': '>24 to ≤48 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 2,
#   'Full Recovery in 3 Months': 'No',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 38,
#   'Sex': 'Male',
#   'Age': 69,
#   'Baseline Score on House–Brackmann scale': 6,
#   'Time between onset of symptoms and start of treatment': '>24 to ≤48 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 39,
#   'Sex': 'Female',
#   'Age': 68,
#   'Baseline Score on House–Brackmann scale': 4,
#   'Time between onset of symptoms and start of treatment': '>24 to ≤48 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 2,
#   'Full Recovery in 3 Months': 'No',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 40,
#   'Sex': 'Male',
#   'Age': 39,
#   'Baseline Score on House–Brackmann scale': 2,
#   'Time between onset of symptoms and start of treatment': '>24 to ≤48 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 2,
#   'Full Recovery in 3 Months': 'No',
#   '9-Month Score on House–Brackmann scale': 2,
#   'Full Recovery in 9 Months': 'No'},
#  {'Patient ID': 41,
#   'Sex': 'Male',
#   'Age': 46,
#   'Baseline Score on House–Brackmann scale': 4,
#   'Time between onset of symptoms and start of treatment': '>24 to ≤48 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 42,
#   'Sex': 'Male',
#   'Age': 36,
#   'Baseline Score on House–Brackmann scale': 5,
#   'Time between onset of symptoms and start of treatment': 'Within 24 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 43,
#   'Sex': 'Male',
#   'Age': 60,
#   'Baseline Score on House–Brackmann scale': 6,
#   'Time between onset of symptoms and start of treatment': '>24 to ≤48 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 44,
#   'Sex': 'Female',
#   'Age': 43,
#   'Baseline Score on House–Brackmann scale': 4,
#   'Time between onset of symptoms and start of treatment': '>24 to ≤48 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 45,
#   'Sex': 'Male',
#   'Age': 34,
#   'Baseline Score on House–Brackmann scale': 3,
#   'Time between onset of symptoms and start of treatment': 'Within 24 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 46,
#   'Sex': 'Male',
#   'Age': 23,
#   'Baseline Score on House–Brackmann scale': 3,
#   'Time between onset of symptoms and start of treatment': '>24 to ≤48 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 47,
#   'Sex': 'Male',
#   'Age': 19,
#   'Baseline Score on House–Brackmann scale': 4,
#   'Time between onset of symptoms and start of treatment': 'Within 24 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 48,
#   'Sex': 'Female',
#   'Age': 61,
#   'Baseline Score on House–Brackmann scale': 3,
#   'Time between onset of symptoms and start of treatment': 'Within 24 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 49,
#   'Sex': 'Female',
#   'Age': 27,
#   'Baseline Score on House–Brackmann scale': 2,
#   'Time between onset of symptoms and start of treatment': 'Within 24 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 50,
#   'Sex': 'Female',
#   'Age': 72,
#   'Baseline Score on House–Brackmann scale': 6,
#   'Time between onset of symptoms and start of treatment': 'Within 24 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 51,
#   'Sex': 'Male',
#   'Age': 44,
#   'Baseline Score on House–Brackmann scale': 5,
#   'Time between onset of symptoms and start of treatment': '>24 to ≤48 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 52,
#   'Sex': 'Male',
#   'Age': 18,
#   'Baseline Score on House–Brackmann scale': 3,
#   'Time between onset of symptoms and start of treatment': 'Within 24 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 53,
#   'Sex': 'Male',
#   'Age': 67,
#   'Baseline Score on House–Brackmann scale': 3,
#   'Time between onset of symptoms and start of treatment': '>24 to ≤48 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 3,
#   'Full Recovery in 3 Months': 'No',
#   '9-Month Score on House–Brackmann scale': 3,
#   'Full Recovery in 9 Months': 'No'},
#  {'Patient ID': 54,
#   'Sex': 'Male',
#   'Age': 45,
#   'Baseline Score on House–Brackmann scale': 2,
#   'Time between onset of symptoms and start of treatment': 'Within 24 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 55,
#   'Sex': 'Male',
#   'Age': 66,
#   'Baseline Score on House–Brackmann scale': 3,
#   'Time between onset of symptoms and start of treatment': '>48 to ≤72 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 56,
#   'Sex': 'Female',
#   'Age': 62,
#   'Baseline Score on House–Brackmann scale': 4,
#   'Time between onset of symptoms and start of treatment': 'Within 24 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 57,
#   'Sex': 'Male',
#   'Age': 32,
#   'Baseline Score on House–Brackmann scale': 3,
#   'Time between onset of symptoms and start of treatment': '>24 to ≤48 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 58,
#   'Sex': 'Male',
#   'Age': 55,
#   'Baseline Score on House–Brackmann scale': 2,
#   'Time between onset of symptoms and start of treatment': '>24 to ≤48 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 2,
#   'Full Recovery in 3 Months': 'No',
#   '9-Month Score on House–Brackmann scale': 2,
#   'Full Recovery in 9 Months': 'No'},
#  {'Patient ID': 59,
#   'Sex': 'Male',
#   'Age': 61,
#   'Baseline Score on House–Brackmann scale': 4,
#   'Time between onset of symptoms and start of treatment': 'Within 24 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 2,
#   'Full Recovery in 3 Months': 'No',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 60,
#   'Sex': 'Male',
#   'Age': 70,
#   'Baseline Score on House–Brackmann scale': 3,
#   'Time between onset of symptoms and start of treatment': 'Within 24 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 61,
#   'Sex': 'Female',
#   'Age': 20,
#   'Baseline Score on House–Brackmann scale': 5,
#   'Time between onset of symptoms and start of treatment': '>24 to ≤48 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 62,
#   'Sex': 'Male',
#   'Age': 38,
#   'Baseline Score on House–Brackmann scale': 3,
#   'Time between onset of symptoms and start of treatment': 'Within 24 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 63,
#   'Sex': 'Male',
#   'Age': 29,
#   'Baseline Score on House–Brackmann scale': 3,
#   'Time between onset of symptoms and start of treatment': '>24 to ≤48 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 64,
#   'Sex': 'Female',
#   'Age': 46,
#   'Baseline Score on House–Brackmann scale': 5,
#   'Time between onset of symptoms and start of treatment': '>24 to ≤48 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 65,
#   'Sex': 'Male',
#   'Age': 42,
#   'Baseline Score on House–Brackmann scale': 5,
#   'Time between onset of symptoms and start of treatment': '>24 to ≤48 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 66,
#   'Sex': 'Female',
#   'Age': 47,
#   'Baseline Score on House–Brackmann scale': 2,
#   'Time between onset of symptoms and start of treatment': '>24 to ≤48 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 67,
#   'Sex': 'Female',
#   'Age': 76,
#   'Baseline Score on House–Brackmann scale': 3,
#   'Time between onset of symptoms and start of treatment': 'Within 24 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 2,
#   'Full Recovery in 3 Months': 'No',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 68,
#   'Sex': 'Female',
#   'Age': 36,
#   'Baseline Score on House–Brackmann scale': 2,
#   'Time between onset of symptoms and start of treatment': 'Within 24 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 69,
#   'Sex': 'Female',
#   'Age': 86,
#   'Baseline Score on House–Brackmann scale': 4,
#   'Time between onset of symptoms and start of treatment': 'Within 24 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 70,
#   'Sex': 'Male',
#   'Age': 67,
#   'Baseline Score on House–Brackmann scale': 4,
#   'Time between onset of symptoms and start of treatment': '>24 to ≤48 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 71,
#   'Sex': 'Male',
#   'Age': 31,
#   'Baseline Score on House–Brackmann scale': 3,
#   'Time between onset of symptoms and start of treatment': '>24 to ≤48 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 72,
#   'Sex': 'Male',
#   'Age': 27,
#   'Baseline Score on House–Brackmann scale': 2,
#   'Time between onset of symptoms and start of treatment': '>48 to ≤72 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 73,
#   'Sex': 'Male',
#   'Age': 37,
#   'Baseline Score on House–Brackmann scale': 3,
#   'Time between onset of symptoms and start of treatment': '>24 to ≤48 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 74,
#   'Sex': 'Female',
#   'Age': 34,
#   'Baseline Score on House–Brackmann scale': 6,
#   'Time between onset of symptoms and start of treatment': 'Within 24 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 75,
#   'Sex': 'Female',
#   'Age': 45,
#   'Baseline Score on House–Brackmann scale': 4,
#   'Time between onset of symptoms and start of treatment': 'Within 24 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 76,
#   'Sex': 'Male',
#   'Age': 70,
#   'Baseline Score on House–Brackmann scale': 4,
#   'Time between onset of symptoms and start of treatment': '>24 to ≤48 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 2,
#   'Full Recovery in 3 Months': 'No',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 77,
#   'Sex': 'Male',
#   'Age': 48,
#   'Baseline Score on House–Brackmann scale': 6,
#   'Time between onset of symptoms and start of treatment': 'Within 24 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 78,
#   'Sex': 'Female',
#   'Age': 41,
#   'Baseline Score on House–Brackmann scale': 2,
#   'Time between onset of symptoms and start of treatment': '>48 to ≤72 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 79,
#   'Sex': 'Male',
#   'Age': 43,
#   'Baseline Score on House–Brackmann scale': 3,
#   'Time between onset of symptoms and start of treatment': 'Within 24 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 80,
#   'Sex': 'Male',
#   'Age': 24,
#   'Baseline Score on House–Brackmann scale': 5,
#   'Time between onset of symptoms and start of treatment': 'Within 24 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 81,
#   'Sex': 'Female',
#   'Age': 34,
#   'Baseline Score on House–Brackmann scale': 4,
#   'Time between onset of symptoms and start of treatment': '>24 to ≤48 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 82,
#   'Sex': 'Female',
#   'Age': 28,
#   'Baseline Score on House–Brackmann scale': 3,
#   'Time between onset of symptoms and start of treatment': '>24 to ≤48 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 83,
#   'Sex': 'Male',
#   'Age': 30,
#   'Baseline Score on House–Brackmann scale': 3,
#   'Time between onset of symptoms and start of treatment': 'Within 24 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 84,
#   'Sex': 'Male',
#   'Age': 42,
#   'Baseline Score on House–Brackmann scale': 4,
#   'Time between onset of symptoms and start of treatment': '>24 to ≤48 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 2,
#   'Full Recovery in 3 Months': 'No',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 85,
#   'Sex': 'Male',
#   'Age': 44,
#   'Baseline Score on House–Brackmann scale': 3,
#   'Time between onset of symptoms and start of treatment': '>24 to ≤48 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 86,
#   'Sex': 'Male',
#   'Age': 24,
#   'Baseline Score on House–Brackmann scale': 3,
#   'Time between onset of symptoms and start of treatment': '>24 to ≤48 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 87,
#   'Sex': 'Male',
#   'Age': 33,
#   'Baseline Score on House–Brackmann scale': 2,
#   'Time between onset of symptoms and start of treatment': 'Within 24 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 88,
#   'Sex': 'Female',
#   'Age': 40,
#   'Baseline Score on House–Brackmann scale': 3,
#   'Time between onset of symptoms and start of treatment': '>24 to ≤48 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 89,
#   'Sex': 'Female',
#   'Age': 42,
#   'Baseline Score on House–Brackmann scale': 4,
#   'Time between onset of symptoms and start of treatment': 'Within 24 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 90,
#   'Sex': 'Female',
#   'Age': 25,
#   'Baseline Score on House–Brackmann scale': 4,
#   'Time between onset of symptoms and start of treatment': '>24 to ≤48 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 91,
#   'Sex': 'Female',
#   'Age': 34,
#   'Baseline Score on House–Brackmann scale': 3,
#   'Time between onset of symptoms and start of treatment': 'Within 24 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 92,
#   'Sex': 'Female',
#   'Age': 56,
#   'Baseline Score on House–Brackmann scale': 3,
#   'Time between onset of symptoms and start of treatment': '>24 to ≤48 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 93,
#   'Sex': 'Female',
#   'Age': 30,
#   'Baseline Score on House–Brackmann scale': 5,
#   'Time between onset of symptoms and start of treatment': 'Within 24 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 94,
#   'Sex': 'Female',
#   'Age': 40,
#   'Baseline Score on House–Brackmann scale': 5,
#   'Time between onset of symptoms and start of treatment': '>24 to ≤48 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 95,
#   'Sex': 'Female',
#   'Age': 36,
#   'Baseline Score on House–Brackmann scale': 4,
#   'Time between onset of symptoms and start of treatment': '>48 to ≤72 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 96,
#   'Sex': 'Male',
#   'Age': 55,
#   'Baseline Score on House–Brackmann scale': 4,
#   'Time between onset of symptoms and start of treatment': 'Within 24 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 97,
#   'Sex': 'Male',
#   'Age': 35,
#   'Baseline Score on House–Brackmann scale': 2,
#   'Time between onset of symptoms and start of treatment': '>24 to ≤48 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 98,
#   'Sex': 'Male',
#   'Age': 44,
#   'Baseline Score on House–Brackmann scale': 4,
#   'Time between onset of symptoms and start of treatment': 'Within 24 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 3,
#   'Full Recovery in 3 Months': 'No',
#   '9-Month Score on House–Brackmann scale': 2,
#   'Full Recovery in 9 Months': 'No'},
#  {'Patient ID': 99,
#   'Sex': 'Male',
#   'Age': 72,
#   'Baseline Score on House–Brackmann scale': 2,
#   'Time between onset of symptoms and start of treatment': 'Within 24 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 100,
#   'Sex': 'Male',
#   'Age': 63,
#   'Baseline Score on House–Brackmann scale': 2,
#   'Time between onset of symptoms and start of treatment': 'Within 24 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 101,
#   'Sex': 'Female',
#   'Age': 59,
#   'Baseline Score on House–Brackmann scale': 2,
#   'Time between onset of symptoms and start of treatment': 'Within 24 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 102,
#   'Sex': 'Male',
#   'Age': 53,
#   'Baseline Score on House–Brackmann scale': 4,
#   'Time between onset of symptoms and start of treatment': '>24 to ≤48 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 103,
#   'Sex': 'Male',
#   'Age': 49,
#   'Baseline Score on House–Brackmann scale': 5,
#   'Time between onset of symptoms and start of treatment': 'Within 24 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 104,
#   'Sex': 'Female',
#   'Age': 33,
#   'Baseline Score on House–Brackmann scale': 2,
#   'Time between onset of symptoms and start of treatment': '>24 to ≤48 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 105,
#   'Sex': 'Male',
#   'Age': 48,
#   'Baseline Score on House–Brackmann scale': 5,
#   'Time between onset of symptoms and start of treatment': '>48 to ≤72 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 2,
#   'Full Recovery in 3 Months': 'No',
#   '9-Month Score on House–Brackmann scale': 2,
#   'Full Recovery in 9 Months': 'No'},
#  {'Patient ID': 106,
#   'Sex': 'Female',
#   'Age': 52,
#   'Baseline Score on House–Brackmann scale': 5,
#   'Time between onset of symptoms and start of treatment': 'Within 24 hr',
#   'Treatment Group': 'Prednisolone–Placebo',
#   'Received Prednisolone': 'Yes',
#   'Received Acyclovir': 'No',
# ...
#   'Treatment Group': 'Placebo–Placebo',
#   'Received Prednisolone': 'No',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 3,
#   'Full Recovery in 3 Months': 'No',
#   '9-Month Score on House–Brackmann scale': 2,
#   'Full Recovery in 9 Months': 'No'},
#  {'Patient ID': 460,
#   'Sex': 'Female',
#   'Age': 29,
#   'Baseline Score on House–Brackmann scale': 2,
#   'Time between onset of symptoms and start of treatment': 'Within 24 hr',
#   'Treatment Group': 'Placebo–Placebo',
#   'Received Prednisolone': 'No',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 461,
#   'Sex': 'Male',
#   'Age': 39,
#   'Baseline Score on House–Brackmann scale': 3,
#   'Time between onset of symptoms and start of treatment': '>24 to ≤48 hr',
#   'Treatment Group': 'Placebo–Placebo',
#   'Received Prednisolone': 'No',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 462,
#   'Sex': 'Female',
#   'Age': 63,
#   'Baseline Score on House–Brackmann scale': 5,
#   'Time between onset of symptoms and start of treatment': '>24 to ≤48 hr',
#   'Treatment Group': 'Placebo–Placebo',
#   'Received Prednisolone': 'No',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 463,
#   'Sex': 'Female',
#   'Age': 36,
#   'Baseline Score on House–Brackmann scale': 3,
#   'Time between onset of symptoms and start of treatment': '>24 to ≤48 hr',
#   'Treatment Group': 'Placebo–Placebo',
#   'Received Prednisolone': 'No',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 464,
#   'Sex': 'Male',
#   'Age': 54,
#   'Baseline Score on House–Brackmann scale': 5,
#   'Time between onset of symptoms and start of treatment': 'Within 24 hr',
#   'Treatment Group': 'Placebo–Placebo',
#   'Received Prednisolone': 'No',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 465,
#   'Sex': 'Female',
#   'Age': 25,
#   'Baseline Score on House–Brackmann scale': 3,
#   'Time between onset of symptoms and start of treatment': 'Within 24 hr',
#   'Treatment Group': 'Placebo–Placebo',
#   'Received Prednisolone': 'No',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 466,
#   'Sex': 'Female',
#   'Age': 42,
#   'Baseline Score on House–Brackmann scale': 6,
#   'Time between onset of symptoms and start of treatment': '>24 to ≤48 hr',
#   'Treatment Group': 'Placebo–Placebo',
#   'Received Prednisolone': 'No',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 2,
#   'Full Recovery in 3 Months': 'No',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 467,
#   'Sex': 'Male',
#   'Age': 62,
#   'Baseline Score on House–Brackmann scale': 4,
#   'Time between onset of symptoms and start of treatment': 'Within 24 hr',
#   'Treatment Group': 'Placebo–Placebo',
#   'Received Prednisolone': 'No',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 3,
#   'Full Recovery in 3 Months': 'No',
#   '9-Month Score on House–Brackmann scale': 3,
#   'Full Recovery in 9 Months': 'No'},
#  {'Patient ID': 468,
#   'Sex': 'Female',
#   'Age': 44,
#   'Baseline Score on House–Brackmann scale': 3,
#   'Time between onset of symptoms and start of treatment': '>24 to ≤48 hr',
#   'Treatment Group': 'Placebo–Placebo',
#   'Received Prednisolone': 'No',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 2,
#   'Full Recovery in 3 Months': 'No',
#   '9-Month Score on House–Brackmann scale': 2,
#   'Full Recovery in 9 Months': 'No'},
#  {'Patient ID': 469,
#   'Sex': 'Female',
#   'Age': 61,
#   'Baseline Score on House–Brackmann scale': 5,
#   'Time between onset of symptoms and start of treatment': 'Within 24 hr',
#   'Treatment Group': 'Placebo–Placebo',
#   'Received Prednisolone': 'No',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 2,
#   'Full Recovery in 3 Months': 'No',
#   '9-Month Score on House–Brackmann scale': 2,
#   'Full Recovery in 9 Months': 'No'},
#  {'Patient ID': 470,
#   'Sex': 'Female',
#   'Age': 90,
#   'Baseline Score on House–Brackmann scale': 6,
#   'Time between onset of symptoms and start of treatment': '>24 to ≤48 hr',
#   'Treatment Group': 'Placebo–Placebo',
#   'Received Prednisolone': 'No',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 2,
#   'Full Recovery in 3 Months': 'No',
#   '9-Month Score on House–Brackmann scale': 2,
#   'Full Recovery in 9 Months': 'No'},
#  {'Patient ID': 471,
#   'Sex': 'Male',
#   'Age': 50,
#   'Baseline Score on House–Brackmann scale': 2,
#   'Time between onset of symptoms and start of treatment': 'Within 24 hr',
#   'Treatment Group': 'Placebo–Placebo',
#   'Received Prednisolone': 'No',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 472,
#   'Sex': 'Female',
#   'Age': 44,
#   'Baseline Score on House–Brackmann scale': 5,
#   'Time between onset of symptoms and start of treatment': '>24 to ≤48 hr',
#   'Treatment Group': 'Placebo–Placebo',
#   'Received Prednisolone': 'No',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 473,
#   'Sex': 'Female',
#   'Age': 34,
#   'Baseline Score on House–Brackmann scale': 2,
#   'Time between onset of symptoms and start of treatment': '>24 to ≤48 hr',
#   'Treatment Group': 'Placebo–Placebo',
#   'Received Prednisolone': 'No',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 474,
#   'Sex': 'Female',
#   'Age': 50,
#   'Baseline Score on House–Brackmann scale': 6,
#   'Time between onset of symptoms and start of treatment': '>24 to ≤48 hr',
#   'Treatment Group': 'Placebo–Placebo',
#   'Received Prednisolone': 'No',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 2,
#   'Full Recovery in 3 Months': 'No',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 475,
#   'Sex': 'Female',
#   'Age': 41,
#   'Baseline Score on House–Brackmann scale': 4,
#   'Time between onset of symptoms and start of treatment': 'Within 24 hr',
#   'Treatment Group': 'Placebo–Placebo',
#   'Received Prednisolone': 'No',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 476,
#   'Sex': 'Male',
#   'Age': 32,
#   'Baseline Score on House–Brackmann scale': 5,
#   'Time between onset of symptoms and start of treatment': '>24 to ≤48 hr',
#   'Treatment Group': 'Placebo–Placebo',
#   'Received Prednisolone': 'No',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 477,
#   'Sex': 'Male',
#   'Age': 24,
#   'Baseline Score on House–Brackmann scale': 3,
#   'Time between onset of symptoms and start of treatment': 'Within 24 hr',
#   'Treatment Group': 'Placebo–Placebo',
#   'Received Prednisolone': 'No',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 478,
#   'Sex': 'Female',
#   'Age': 54,
#   'Baseline Score on House–Brackmann scale': 5,
#   'Time between onset of symptoms and start of treatment': '>24 to ≤48 hr',
#   'Treatment Group': 'Placebo–Placebo',
#   'Received Prednisolone': 'No',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 479,
#   'Sex': 'Male',
#   'Age': 22,
#   'Baseline Score on House–Brackmann scale': 4,
#   'Time between onset of symptoms and start of treatment': '>24 to ≤48 hr',
#   'Treatment Group': 'Placebo–Placebo',
#   'Received Prednisolone': 'No',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 480,
#   'Sex': 'Male',
#   'Age': 20,
#   'Baseline Score on House–Brackmann scale': 2,
#   'Time between onset of symptoms and start of treatment': 'Within 24 hr',
#   'Treatment Group': 'Placebo–Placebo',
#   'Received Prednisolone': 'No',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 481,
#   'Sex': 'Male',
#   'Age': 29,
#   'Baseline Score on House–Brackmann scale': 2,
#   'Time between onset of symptoms and start of treatment': 'Within 24 hr',
#   'Treatment Group': 'Placebo–Placebo',
#   'Received Prednisolone': 'No',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 482,
#   'Sex': 'Female',
#   'Age': 45,
#   'Baseline Score on House–Brackmann scale': 4,
#   'Time between onset of symptoms and start of treatment': '>24 to ≤48 hr',
#   'Treatment Group': 'Placebo–Placebo',
#   'Received Prednisolone': 'No',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 483,
#   'Sex': 'Female',
#   'Age': 37,
#   'Baseline Score on House–Brackmann scale': 3,
#   'Time between onset of symptoms and start of treatment': '>24 to ≤48 hr',
#   'Treatment Group': 'Placebo–Placebo',
#   'Received Prednisolone': 'No',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 484,
#   'Sex': 'Male',
#   'Age': 77,
#   'Baseline Score on House–Brackmann scale': 6,
#   'Time between onset of symptoms and start of treatment': 'Within 24 hr',
#   'Treatment Group': 'Placebo–Placebo',
#   'Received Prednisolone': 'No',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 4,
#   'Full Recovery in 3 Months': 'No',
#   '9-Month Score on House–Brackmann scale': 4,
#   'Full Recovery in 9 Months': 'No'},
#  {'Patient ID': 485,
#   'Sex': 'Female',
#   'Age': 60,
#   'Baseline Score on House–Brackmann scale': 5,
#   'Time between onset of symptoms and start of treatment': '>24 to ≤48 hr',
#   'Treatment Group': 'Placebo–Placebo',
#   'Received Prednisolone': 'No',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 2,
#   'Full Recovery in 3 Months': 'No',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 486,
#   'Sex': 'Female',
#   'Age': 53,
#   'Baseline Score on House–Brackmann scale': 3,
#   'Time between onset of symptoms and start of treatment': '>24 to ≤48 hr',
#   'Treatment Group': 'Placebo–Placebo',
#   'Received Prednisolone': 'No',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 487,
#   'Sex': 'Male',
#   'Age': 60,
#   'Baseline Score on House–Brackmann scale': 4,
#   'Time between onset of symptoms and start of treatment': '>24 to ≤48 hr',
#   'Treatment Group': 'Placebo–Placebo',
#   'Received Prednisolone': 'No',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 2,
#   'Full Recovery in 3 Months': 'No',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 488,
#   'Sex': 'Female',
#   'Age': 40,
#   'Baseline Score on House–Brackmann scale': 3,
#   'Time between onset of symptoms and start of treatment': '>24 to ≤48 hr',
#   'Treatment Group': 'Placebo–Placebo',
#   'Received Prednisolone': 'No',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 2,
#   'Full Recovery in 3 Months': 'No',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 489,
#   'Sex': 'Male',
#   'Age': 34,
#   'Baseline Score on House–Brackmann scale': 4,
#   'Time between onset of symptoms and start of treatment': 'Within 24 hr',
#   'Treatment Group': 'Placebo–Placebo',
#   'Received Prednisolone': 'No',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 490,
#   'Sex': 'Male',
#   'Age': 40,
#   'Baseline Score on House–Brackmann scale': 5,
#   'Time between onset of symptoms and start of treatment': '>24 to ≤48 hr',
#   'Treatment Group': 'Placebo–Placebo',
#   'Received Prednisolone': 'No',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 2,
#   'Full Recovery in 3 Months': 'No',
#   '9-Month Score on House–Brackmann scale': 2,
#   'Full Recovery in 9 Months': 'No'},
#  {'Patient ID': 491,
#   'Sex': 'Male',
#   'Age': 37,
#   'Baseline Score on House–Brackmann scale': 3,
#   'Time between onset of symptoms and start of treatment': '>24 to ≤48 hr',
#   'Treatment Group': 'Placebo–Placebo',
#   'Received Prednisolone': 'No',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 492,
#   'Sex': 'Female',
#   'Age': 56,
#   'Baseline Score on House–Brackmann scale': 3,
#   'Time between onset of symptoms and start of treatment': '>24 to ≤48 hr',
#   'Treatment Group': 'Placebo–Placebo',
#   'Received Prednisolone': 'No',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 493,
#   'Sex': 'Male',
#   'Age': 33,
#   'Baseline Score on House–Brackmann scale': 4,
#   'Time between onset of symptoms and start of treatment': 'Within 24 hr',
#   'Treatment Group': 'Placebo–Placebo',
#   'Received Prednisolone': 'No',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 3 Months': 'Yes',
#   '9-Month Score on House–Brackmann scale': 1,
#   'Full Recovery in 9 Months': 'Yes'},
#  {'Patient ID': 494,
#   'Sex': 'Female',
#   'Age': 34,
#   'Baseline Score on House–Brackmann scale': 5,
#   'Time between onset of symptoms and start of treatment': 'Within 24 hr',
#   'Treatment Group': 'Placebo–Placebo',
#   'Received Prednisolone': 'No',
#   'Received Acyclovir': 'No',
#   '3-Month Score on House–Brackmann scale': 4,
#   'Full Recovery in 3 Months': 'No',
#   '9-Month Score on House–Brackmann scale': 4,
#   'Full Recovery in 9 Months': 'No'}]
